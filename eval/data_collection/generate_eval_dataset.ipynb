# %%
import os
from neo4j import GraphDatabase
import pandas as pd
from dotenv import load_dotenv

load_dotenv()

graph = GraphDatabase.driver(
	os.environ['NEO4J_URI'],
	auth=(os.environ['NEO4J_USER'], os.environ['NEO4J_PWD'])
)
database = os.environ['NEO4J_DATABASE']


def get_single_facts_by_title(k: int):
    query = '''
    MATCH (f:Fact)
	WHERE NOT (f.title IN $titles_to_ignore)
    WITH DISTINCT f.title AS fact_title
    CALL (fact_title) {
		MATCH (b:Bird)-[:HAS_FACT]->(f:Fact {title: fact_title})
		WITH DISTINCT b, fact_title
		CALL (b, fact_title) {
			MATCH (b)-[:HAS_FACT]->(f:Fact {title: fact_title})
			WITH f
			ORDER BY rand()
			LIMIT 1
			RETURN f
		}
		WITH b, f
		ORDER BY rand()
		LIMIT $k
		RETURN 
  			b.name AS bird_name, 
     		f.title AS title, 
       		f.text AS text
    }
    RETURN bird_name, title, text
    '''
    with graph.session(database=database) as session:
        records = session.run(
            query, 
            k=int(k),
			titles_to_ignore=[
				'About the Author(s)',
				'Acknowledgments',
				'Introduction',
				'Introduction?login'
			]
        )
        return [{ **r } for r in records]


test_facts = get_single_facts_by_title(1)
test_facts
# Out:
# [{'bird_name': 'Rufous-sided Gerygone',
#   'title': 'Identification',
#   'text': '10 cm. Has short pale supercilium not extending behind eye, narrow pale eyering; crown olive-brown, rest of upper\xadparts, including upperwing, reddish-brown; tail red-brown, inconspicuous pale subterminal spots on outer rectrices; white below, pale rufous-ochre on breast side and flanks; iris variously red-brown, dark grey or yellow-grey; bill blackish-grey; legs dark greyish. Sexes alike. Juvenile has underparts washed pale yellow. Races differ minimally in size and plumage colour: kuehni darker and duller above, with greyer brown crown and somewhat redder sides and flanks; fulvescens very similar to previous, but slightly less reddish on upperparts and on sides and flanks; senex extremely similar to previous, possibly slightly duller and greyer above, with darker, ashier crown; keyensis slightly larger, but otherwise barely separable.'},
#  {'bird_name': 'Western Barn Owl',
#   'title': 'Similar Species',
#   'text': 'No similar owl over much of range (but in the Afrotropics, subspecies poensis overlaps with African Grass-Owl (Tyto capensis), which is longer-legged and usually notably darker).Western Barn Owl (subspecies poensis).Possible confusion species: African Grass-Owl (Tyto capensis).Possible confusion species: African Grass-Owl (Tyto capensis).'},
#  {'bird_name': 'Rimatara Reed Warbler',
#   'title': 'Systematics History',
#   'text': 'See Pitcairn Reed Warbler (Acrocephalus vaughani). Monotypic.'},
#  {'bird_name': 'Pacific Robin',
#   'title': 'Geographic Variation',
#   'text': 'Subspecies vary mainly in plumage coloration, including amount of white, and in degree of sexual dimorphism, extent of female-like male plumage and male-like female plumage, size, and proportions.'},
#  {'bird_name': 'South American Tern',
#   'title': 'Subspecies',
#   'text': 'Monotypic.'},
#  {'bird_name': 'Gray Monjita',
#   'title': 'Distribution',
#   'text': "Editor's Note: Additional distribution information for this taxon can be found in the 'Subspecies' article above. In the future we will develop a range-wide distribution article."},
#  {'bird_name': 'White-throated Screech-Owl',
#   'title': 'General Habitat',
#   'text': 'Humid montane evergreen forest and cloudforest, especially stunted alpine forest; mostly open forest and edge, and semi-open areas with scattered trees; habitat often rich in epiphytes and bamboo thickets, sometimes with glades or at least gaps in canopy. Occurs mostly from 2,000–3,000 m elevation, but locally down to 1,300 m (1) and as high as 3,700 m on eastern slope of the Peruvian Andes (14).'},
#  {'bird_name': 'Fly River Grassbird',
#   'title': 'Movements and Migration',
#   'text': 'Resident.'},
#  {'bird_name': 'Rufous-winged Buzzard',
#   'title': 'Diet and Foraging',
#   'text': 'Small mammals, snakes, lizards, frogs, crabs and large insects (2, 1). Hunts from exposed perch, making short flights to ground to capture prey and less often hawking prey during short circular flights from perch (1). Regularly soars.'},
#  {'bird_name': 'Oriental Reed Warbler',
#   'title': 'Sounds and Vocal Behavior',
#   'text': 'Song, delivered from exposed perch (top of reed or bush, or even wire, roof or TV antenna close to reeds), loud, very harsh and dry chattering, “kiruk kiruk kiruk, jee jee jee”, similar to song of A. arundinaceus. Calls quiet “krak”, also “chichikarr”, “kirr”, and hoarse “si-si-si-si”.'},
#  {'bird_name': 'Black-throated Canary',
#   'title': 'Breeding',
#   'text': 'Season Sept–Jun (mainly Nov–Jan or Dec–Apr) in Zambia and Jun–Apr (mainly Oct–Mar) in South Africa; probably two broods. Monogamous. Solitary nester; territorial. Displaying male sings during circular butterfly-like flight with slow stiff wingbeats, lands near female on perch in tree, and with wings half-spread and swaying from side to side approaches female, which flies off with male in pursuit; on landing, male jumps over her from side to side. Nest built by both sexes, a neat cup of dry grasses, fine twigs, plant tendrils (frequently those of Asparagus), plant-fibre strips and woolly plant down (proteas), some feathers and coarse or dry cobwebs, usually well concealed 1–15 m above ground in fork of tree or among slender outer foliage or flowerhead in Protea bush, at base of palm frond, or in fir among cones; has also nested on rafter in shed. Clutch 2–4 eggs, white or pale greenish-blue, sometimes with fine specks of black, brown or purple; incubation by female only, fed on nest by male throughout, period 12–13 days; chicks fed by both parents, nestling period 15–17 days; fledglings tended by both parents.'},
#  {'bird_name': 'Lesser Grass-Finch',
#   'title': 'Conservation Status',
#   'text': 'Conservation status on BirdlifeLCLeast ConcernNot globally threatened (Least Concern). Uncommon to fairly common throughout range.'},
#  {'bird_name': 'Puerto Rican Parakeet',
#   'title': 'Vernacular Names',
#   'text': 'Apart from general uncertaintity about the taxonomic relationships of the taxa presently included in Psittacara (see 18), leading to shifting generic-level classifications, the general lack of specimens of P. maugei, particularly those known origin, has historically led to a fair amount of confusing taxonomic synonomy (see exellent summary in 3). One name in particular, Conurus gundlachi (19, 20), was a particularly wide-spread synonym (21, 3). Under a variety of generic names, most authors have historically considered maugei as subspecifically related to P. holochlorus (e.g., 22, 1, 23, 24, 25, 10). Again, however, due largely to ambiguities surrounding the historical distribution and taxonomic validity of P. maugei, some works seemingly avoided mention of maugei, lumping it under P. chloropterus without comment (e.g., 26, 27). Still others (e.g., 28, 13, 29) returned maugei to full species status. Although far from complete, following guide to P. maugei synonyms (arranged alphabetically) will be a useful tool for navigating early literature that deals with the scant information available about the Puerto Rican Parakeet.Aratinga chloroptera maugaei (12)Aratinga chloroptera maugei (1, 30, 23, 31, 32, 2, 7, 6, 33, 5)Aratinga chloroptera (15, 27 [in part], 34)Aratinga maugei (13)Conurus chloropterus (35, 36, 14)Conurus euops Gundlachi (37)Conurus gundlachi (19, 19, 38, 39, 22)Conurus maugei (40, 21)Conurus maugei (?) (41)'},
#  {'bird_name': 'Semicollared Flycatcher',
#   'title': 'Hybridization',
#   'text': 'Hybrid Records and Media Contributed to eBirdSemicollared x European Pied Flycatcher (hybrid)Ficedula semitorquata x hypoleucaeBird map 0  s 0 RecordingsSemicollared x Collared Flycatcher (hybrid)Ficedula semitorquata x albicolliseBird map 0  s 0 Recordings'},
#  {'bird_name': 'Yellow-breasted Forest Robin',
#   'title': 'Eggs',
#   'text': 'Two eggs, olive green to greenish blue with heavy russet, orange brown, pale chestnut and/or mauve blotching. 20.7–21.7 mm × 14.3–14.7 mm.'},
#  {'bird_name': 'Squamate Antbird',
#   'title': 'Parental Care',
#   'text': 'Both sexes shared incubation and brooding (2).'},
#  {'bird_name': 'Minas Gerais Tyrannulet',
#   'title': 'Plumages',
#   'text': 'Minas Gerais Tyrannulets have 10 full-length primaries (numbered distally, from innermost p1 to outermost p10), 9 secondaries (numbered proximally, from innermost s1 to outermost s9 and including 3 tertials, s7–s9 in passerines), and 12 rectrices (numbered distally from innermost r1 to outermost r6 on each side of the tail). Little or no geographic variation in plumage has been reported (see Systematics); the following descriptions are based on those of Ridgely and Tudor (1) and Fitzpatrick et al. (2), along with examination of Macaulay Library images; see Pyle (3) for criteria used for age and sex determinations of similar tyrannid flycatchers. See Molts for molt and plumage terminology. Sexes are similar in all plumages; definitive appearance is assumed at the Second Basic Plumage. Timing of plumages relates to timing of molts, which appears to peak primarily in December-March following breeding primarily in October-January (see Breeding Phenology and Molts).Natal DownOccurs in the nest, perhaps primarily in November-December. No information on natal down in Minas Gerais Tyrannulet but in the congeneric Mottle-cheeked Tyrannulet (Phylloscartes ventralis) nestlings are covered with sparse gray natal down.Juvenile (First Basic) PlumageAppears to occur primarily in December-February. Similar to later plumages but body feathering is duller and paler. Crown and upperparts washed brown; underparts pale yellow with diffuse olive streaking. Upperwing median and greater coverts weaker and perhaps with buff or yellowish tips. Juvenile body feathering is more filamentous than that of later plumages due to lower barb densities. Juvenile flight feathers are narrower and more pointed than later generations and are fresh at a time of year when older birds are typically worn and/or molting.Juvenile Minas Gerais Tyrannulet.Juvenile Minas Gerais Tyrannulet.Juvenile Minas Gerais Tyrannulet.Formative PlumageAppears to occur primarily in March (when fresh) to February (when worn). Examination of Macaulay Library images indicates that the Preformative Molt is partial and that Formative Plumage is identified by molt limits among wing and sometimes tail feathers. Most to all upperwing secondary coverts and occasionally 1–2 inner tertials are replaced, and are fresher and blacker, contrasting with the more worn and browner, retained juvenile primary coverts and tertials or inner secondaries. Retained juvenile outer primaries and rectrices are narrow, tapered or pointed at the tips, abraded, and brownish; occasionally all rectrices may be replaced (see Molts) or perhaps more frequently, 1-2 pairs of inner rectrices are replaced and contrastingly gray and fresh.Formative Minas Gerais Tyrannulet.Formative Minas Gerais Tyrannulet.Formative Minas Gerais Tyrannulet.Definitive Basic PlumageAppears to occur primarily in March (when fresh) to February (when worn). Upperparts bright olive, the lores, sides of the forecrown and often the forehead washed rufous to ochraceous. Upperwing and tail feathers dusky, the median and greater coverts tipped pale yellow to whitish forming distinct wing bars, and the remaining remiges and rectrices distinctly edged white (tertials) to bright olive-yellow on the outer webs at the bases. Sides of head with indistinct yellowish super\xadcilium, whitish eyering, and yellowish auriculars and malar region with a variably distinct to indistinct (or almost lacking) brownish crescent-shaped mark to the lores, suborbital area, and proximal auriculars. Underparts bright lemon yellow (when fresh) with diffuse olive streaking across breast and sides forming indistinct band or vested appearance. Underwing coverts appear to be pale lemon yellow (cf. ML463910311).Distinguished from Formative Plumage by having wing and tail feathers uniform in quality, lacking molt limits among upperwing coverts and tertials/inner secondaries. Primary coverts are black to blackish, forming a distinct black triangular patch not contrasting in qua ...
#  {'bird_name': 'Amur Stonechat',
#   'title': 'Migration Overview',
#   'text': 'Common Stonechat (Saxicola torquatus)Sedentary, altitudinal migrant, partial migrant and migrant. W of line from Britain to Italy, also Balkans and C Turkey, populations sedentary or partial migrants, but Irish birds fully migratory and all other European breeders move S (passage in Spain from Sept, but mostly in Nov) and winter across N Africa in large numbers, with particularly strong representation near Algerian coast; many rubicola and variegatus occupy N Africa chiefly Oct–Mar. In Tunisia most breeders appear to disperse into desert in winter. Numbers of juveniles wintering in Spain falls over time while numbers of adults stay constant, suggesting that juveniles move farther S. Those wintering commonly in C & E Mediterranean presumably originate in SE Europe and Turkey, and populations in Ukraine and W Caucasus may also move to E Mediterranean and Middle East. Race variegatus migrates through E Transcaucasia Sept and Mar and via Iraq and Arabia, recorded Eritrea mid-Sept to end Mar; variegatus winters across Iraq and Arabia into NE Africa. In Israel, rubicola a very common passage migrant, with peaks in Nov and Mar; maurus, variegatus much rarer, but with essentially same dates; over winters with good rainfall numbers fairly constant, but with poor rainfall unpaired juveniles (high proportion of total) move out. In Jordan present mainly early Nov to mid-Mar. In UAE, rubicola fairly common winter visitor Nov to early Mar, with “maurus group” on irregular passage Sept and Apr, and similar pattern Bahrain. Scarce winter visitor in E Saudi Arabia late Aug to Feb (mainly from Oct), presumed maurus/stejnegeri, but passage of apparent variegatus in Mar. Race indicus extensively penetrates Indian Subcontinent, reaching extreme S areas of winter range Oct–Feb, moving N and upslope over Mar–Apr. Race przewalskii apparently resident in much of lowland range, including SW China, although possibly a partial migrant in some regions, and in high W of range on Tibetan Plateau fully migratory, departing mid-Oct to E Himalayan foothills and returning mid-Apr. Race stejnegeri leaves Russian breeding grounds second half Aug but Korean Peninsula not until early Oct (return there late Mar), with passage in Japan late Sept and Oct (return mid-Apr to early May), wintering N India and Myanmar E to S China; main autumn passage at Beidaihe (NE China) mid-Aug to mid-Oct, occupying coastal SE China, Taiwan and Hainan mostly mid-Oct to end Mar or early Apr; stragglers reach Singapore, N Borneo and Sumatra. Race maurus is a frequent vagrant to W Europe, while records of race stejnegeri has been proved also, by means of DNA analysis, at least in Sweden (Oct 2008), England (Oct 2012) and Finland (Nov 2013) (10).  In tropical Africa appears to be sedentary, or vertical migrant (some breeding at 1000–2000 m in Malawi descend to 450 m), or short-distance migrant; birds breeding in Lesotho descend lower in winter but some disperse as far as E Zimbabwe; those from E South Africa move into S Mozambique; and in Sierra Leone more pairs noted at 1370 m on Mt Bintimani in Apr than in Nov, suggesting upward spring movement.'},
#  {'bird_name': 'Golden-spotted Ground Dove',
#   'title': 'Other',
#   'text': 'Cultural significanceAymara and Quechua communities in El Loa (Northern Chile), they mentioned that they see this species as “A dove from the field. They turn into mice and that is why when there are many pigeons in the field you know that that year will be bad for the crops, because the mouse will eat them. The pigeons get into the mouse\'s nest and lay their eggs there." Other interviewed people said that "That\'s why those mice have feathers instead of hair." “There are a lot of pigeons in Turi, just one kind. Pretty pigeons, little one. They call him tupu. Little ones with lead, little white ones. They are like gold. Pretty little head." (4).'},
#  {'bird_name': 'Chiriqui Foliage-gleaner',
#   'title': 'Nest',
#   'text': 'Nest a broad, shallow cup of a single type of plant fiber (usually rachides of compound leaves) placed in expanded chamber at end of horizontal tunnel c. 40–75 cm long, excavated in dirt bank (Skutch (13, 15) ).'},
#  {'bird_name': 'Chestnut-bellied Chat-Tyrant',
#   'title': 'Predation',
#   'text': 'No information.'},
#  {'bird_name': 'Australian Rufous Fantail',
#   'title': 'Measures of Breeding Activity',
#   'text': 'Hatching success 37.3–62.8 %. fledging success low, in one study 15.7%.'},
#  {'bird_name': 'Pacific Baza',
#   'title': 'Causes of Mortality',
#   'text': 'Storms sometimes destroy nests and eggs or young.'},
#  {'bird_name': 'West African Crested Tern',
#   'title': 'Population Regulation',
#   'text': 'No information beyond likelihood that extremely extended parental care of (normally single) juvenile well into its second calendar year (37, 26) and single-egg clutches indicate slow development of skills needed for difficult prey capture. Frequent washouts of low-lying colonies often result in re-laying, at same site or new one. Colonies deserted easily in egg stage, but not later. Adult mortality probably not limiting, but that of young in first winter may be (see Causes of mortality, above). Food probably not limiting, but colonies need sites on isolated islands, free of mammalian predators, especially at/near inlets/passes with high fish productivity.'},
#  {'bird_name': 'Sunda Thrush',
#   'title': 'Historical Changes to the Distribution',
#   'text': "The species is now also known from East Java and has been located in the environs of Gunung Welirang at some 1600 masl where it is considered very rare. It has also been reported by local guides from the locality of Gunung Ijen on the eastern tip of Java. This perhaps fills in some gaps in known range from Sumatra and West Java east towards it's other known locations in the Lesser Sundas."},
#  {'bird_name': 'Crab-Plover',
#   'title': 'Sexual Behavior',
#   'text': 'Mating System and Operational Sex RatioProbably monogamous (34).Courtship, Copulation, and Pair BondRather elaborate courtship display involving much vocalizing, at least within the environs of the colony (31).'},
#  {'bird_name': 'Common Babbler',
#   'title': 'Population Spatial Metrics',
#   'text': 'Territory SizeTerritory size in Delhi (India) 2·4–5·9 ha (mean 4 ha), but in low-density areas territories can be much bigger.'},
#  {'bird_name': 'Salmon-crested Cockatoo',
#   'title': 'Social and Interspecific Behavior',
#   'text': 'Usually occurs in small numbers, singly or in pairs, though up to 16 may roost together at regular sites in nonbreeding season (1). However, even by late 1980s, flocks greater than four were seemingly rare in parts of Seram (4).'},
#  {'bird_name': 'Slaty-capped Flycatcher',
#   'title': 'Diet',
#   'text': 'Arthropods; also small fruit and berries. Stomach contents in southeastern Peru (albidiventris) contained 108 food items, of which lepidopteran larvae 25%, beetles (Coleoptera) 22%, orthopterans 22%, homopteran bugs (planthoppers) 9%, ants (Hymenoptera) 8%, spiders (Araneae) 7%, hemipterans 5%, other items 2%.Bird feeding on insect.Bird feeding on moth.Bird feeding on insect larvae.'},
#  {'bird_name': 'Louisiade Fantail',
#   'title': 'Agonistic Behavior',
#   'text': 'Territorial BehaviorPresumably territorial, as Australian Rufous Fantail (Rhipidura rufifrons).'},
#  {'bird_name': 'Salinas Monjita',
#   'title': 'Phenology',
#   'text': 'A nest with chicks was found in December in San José de las Salinas (2).'},
#  {'bird_name': 'Sunda Thrush',
#   'title': 'Nest Site',
#   'text': 'In one observation, a nest was sited 4.6 m up in tree fork (BS, personal observation).'},
#  {'bird_name': 'Yellow-billed Pintail',
#   'title': 'Incubation',
#   'text': 'c. 26 days (spinicauda) or 24–28 days (georgica) (1), by female alone, guarded by male (1).'},
#  {'bird_name': 'Rosy Pipit',
#   'title': 'Hatching',
#   'text': 'Information needed.'},
#  {'bird_name': 'West African Crested Tern',
#   'title': 'Cooperative Breeding',
#   'text': 'Unknown, but unlikely.'},
#  {'bird_name': 'Yellow-breasted Pipit',
#   'title': 'Population Status',
#   'text': 'Rare in Lesotho, known only from Sehlabethebe National Park, where ca. 60–80 pairs. Global population estimated at 1,500–5,000 individuals in 1992, but reassessed as between 2,500 and 6,500 in 2000. Occurs in Natal Drakensberg National Park; significant numbers, ca. 30% of total population, occur in proposed grassland biosphere reserve in Wakkerstroom region of southern Mpumalanga and adjacent KwaZulu-Natal.'},
#  {'bird_name': "Newton's Parakeet",
#   'title': 'Effects of Human Activity',
#   'text': 'A combination of hunting and habitat loss had presumably considerably reduced the species’ numbers.'},
#  {'bird_name': 'Sula Lorikeet',
#   'title': 'Young Birds',
#   'text': 'Very little information. In captivity, nestling period about 65 days or less.'},
#  {'bird_name': 'Common Chaffinch',
#   'title': 'Life Span and Survivorship',
#   'text': 'Longevity at least 14 years.'},
#  {'bird_name': 'Minahasa Hooded Pitta',
#   'title': 'Bare Parts',
#   'text': 'BillIn adults, the bill and inside of the maxilla are blackish.Iris and Facial SkinDark or deep brown with a plumbeous orbital ring, and orange eyelids.Tarsi and ToesPale brown to pinkish, or dark to purplish pink, or even slate gray; soles of feet paler, and claws pink.'},
#  {'bird_name': 'Little Woodswallow',
#   'title': 'Feeding',
#   'text': 'Captures prey generally in flight; occasionally among foliage or flowers, or on ground. Forages singly and in pairs, also in small flocks; occasionally in mixed-species flocks, usually with congeners.'},
#  {'bird_name': 'Indian Cuckooshrike',
#   'title': 'Vocalizations',
#   'text': "Vocal DevelopmentNo information.Vocal ArraySong. Said to be a quaint, melodious warble that is rarely heard (23). It is unclear if this is different from the Querulous call detailed below.Main call.audio2 A single shrill, grating note skreeEk, not unlike a parakeet. Note duration 0.34–0.52s and maximum frequency 4.0–5.7kHz (9). Note is typically repeated several times at intervals of a few seconds. Calls are loud and audible from a considerable distance. This is the commonest vocalization.Querulous call.audioVariable chuckling notes heard at close range that include querulous, conversational sounds kerr-i-ou, ko-iree, ko-i-rik, etc.Geographic VariationPreviously was treated as a single species 'Large Cuckooshrike', together with Malayan Cuckooshrike (Coracina larutensis) and Oriental Cuckooshrike (Coracina javensis) (in part). Vocal differences between these three species are rather subtle, but Main call of Coracina macei differs from Coracina javensis in reaching higher frequencies and having a predominantly rising note shape (vs. fairly flat with modulation), while Coracina larutensis call is clearly different, shorter and simpler, rather symmetrically overslurred (9). Vocal diversification in the entire genus is rather limited in general. Geographic variation within present species unknown.PhenologyLittle information. Main call can be heard throughout the year.Daily Pattern of VocalizingMain call is mainly heard during the morning and again in late afternoon.Places of VocalizingMain call is uttered both from a perch in the canopy or in flight.Sex DifferencesMain call presumably is uttered by both sexes.Social Context and Presumed Functions of VocalizationsLittle information. Main call is used to maintain contact between members of a pair."},
#  {'bird_name': 'Manipur Bush-Quail',
#   'title': 'Fledgling Stage',
#   'text': 'Information needed. A fully-fledged chick was collected in Jan (1).'},
#  {'bird_name': 'Southern Royal Albatross',
#   'title': 'Management',
#   'text': 'Conservation AreasAll breeding islands are nature reserves and, in 1998, were declared a World Heritage Site.Conservation Measures and Habitat ManagementCattle and rats were eradicated from Campbell, and sheep have been removed from parts of the island (2), while cattle, rabbits, and mice have all been eradicated from Enderby.'},
#  {'bird_name': 'Black-crowned Scimitar-Babbler',
#   'title': 'Related Species',
#   'text': 'In a molecular phylogeny of the genus, Pomatorhinus ferruginosus was found to be sister to Brown-crowned Scimitar-Babbler (Pomatorhinus phayrei) (4, 5). Together, these two species appeared to be sister to Red-billed Scimitar-Babbler (Pomatorhinus ochraceiceps) (4, 6).'},
#  {'bird_name': 'Blackish Chat-Tyrant',
#   'title': 'Fossils',
#   'text': 'None reported.'},
#  {'bird_name': 'European Herring Gull',
#   'title': 'Locomotion',
#   'text': 'This section is derived mainly from the following: 100, 96, 101, 102, 103, as summarized in 7.Walking, Hopping, ClimbingOn land, the European Herring Gull typically walks or runs. It can jump or hop onto perches by opening its wings, pushing off with its legs and using a single wingbeat to lift. It also hops down with wings partially spread. In agonistic charges, it runs with wings partially upraised. It also runs to take off for flight. It does not hop or climb vertical objects.seekmute0:00 / 0:23Birds walking.© Josep del HoyoEast Lothian, Scotland, United Kingdom 13 Aug 2017Macaulay Library ML 201471001eBirdS64823036FlightThe species will adjust its wingbeats and orientation to the wind to regulate its speed. It spends a considerable portion of its flight time gliding or soaring with outstretched wings and often flies close to the water surface, especially when flying against the wind; it will also often fly at altitudes of 30–300 m, especially when commuting overland or flying downwind over water.seekmute0:00 / 0:16Birds flying.© Josep del HoyoFinnmark, Norway 02 Jun 2014Macaulay Library ML 201402261eBirdS64822946Swimming and DivingThe European Herring Gull swims using a paddling motion of the legs for propulsion. It can dive either from the surface or from 50–100 cm above the water, but it cannot reach depths > 1–2 m below the surface because of its buoyancy (96).seekmute0:00 / 0:24Bird swimming.© Greg BakerCheshire, England, United Kingdom 04 Jan 2013Macaulay Library ML 201844611eBirdS65137755'},
#  {'bird_name': 'Cyprus Scops-Owl',
#   'title': 'Molts',
#   'text': 'No information.'},
#  {'bird_name': 'Brujo Flycatcher',
#   'title': 'Measurements',
#   'text': 'Linear MeasurementsSee Table 2. Male averages slightly (but not significantly) larger than female in most measurements, but much overlap.MassTable 2. No significant weight differences between the sexes.'},
#  {'bird_name': "Bocage's Akalat",
#   'title': 'Nonvocal Sounds',
#   'text': 'None documented.'},
#  {'bird_name': 'Moss-backed Tanager',
#   'title': 'Behavior',
#   'text': 'The chunky Moss-backed Tanager flies directly from tree to tree with a heavy, buzzy flight (Isler and Isler 1987). They often hop slowly along moss-laden branches, sometimes hopping with 180° turns (Restall et al. 2006). They will perch for long periods without moving, but generally perch in the open so are not difficult to see (Ridgely and Greenfield 2001). They have been observed frequently perched quietly on a open perch overlooking the forest (Hilty and Brown 1986).'},
#  {'bird_name': 'Inambari Gnatcatcher',
#   'title': 'Demography and Populations',
#   'text': 'There are no data on lifespan, population regulation, or other demographic parameters for Inambari Gnatcatcher.'},
#  {'bird_name': 'Fiji Petrel',
#   'title': 'Priorities for Future Research',
#   'text': 'Priorities include the localization and protection of the breeding grounds (surveys in February 1925, October 1972, July–August 1982, May 1983–August 1984, June 1985, September–October 1987, March 1989, and June 2003 all failed) (7), and also gathering information on biology, ecology, and conservation requirements; research already in progress, but considerable efforts are required due to the apparently elusive nature of the species.'},
#  {'bird_name': 'Rufous-browed Chat-Tyrant',
#   'title': 'Food Selection and Storage',
#   'text': 'Information needed.'},
#  {'bird_name': 'Dusky-legged Guan',
#   'title': 'Nutrition and Energetics',
#   'text': 'Information needed.'},
#  {'bird_name': 'Thorn-tailed Rayadito',
#   'title': 'Metabolism and Temperature Regulation',
#   'text': 'A Corporal Condition Index calculated in Maule, central Chile, was lower in winter than in spring and summer (18).'},
#  {'bird_name': 'Rufous-browed Chat-Tyrant',
#   'title': 'Drinking, Pellet Casting, and Defecation',
#   'text': 'Information needed.'},
#  {'bird_name': 'Common Babbler',
#   'title': 'Brood Parasitism',
#   'text': 'Brood parasitism by Jacobin Cuckoo (Clamator jacobinus) and Common Hawk-cuckoo (Hierococcyx varius) reported.'},
#  {'bird_name': 'Square-tailed Kite',
#   'title': 'Similar Species Summary',
#   'text': 'Distinguished from other Australian raptors by a combination of size, plumage, bare parts, structure, and flight behavior. Square-tailed Kite is most likely to be confused with other reddish-brown raptors, including juvenile or immature Black-breasted Kite (Hamirostra melanosternon), Black Kite (Milvus migrans), female Swamp Harrier (Circus approximans), Red Goshawk (Erythrotriorchis radiatus), and Little Eagle (Hieraaetus morphnoides). It may also be confused with Whistling Kite (Haliastur sphenurus) and, at a distance, Wedge-tailed Eagle (Aquila audax).'},
#  {'bird_name': 'Augur Buzzard',
#   'title': 'Dispersal and Site Fidelity',
#   'text': 'Information needed.'},
#  {'bird_name': 'Western Barn Owl',
#   'title': 'Pathogens and Parasites',
#   'text': 'DiseaseThere is little evidence in Europe that bacterial or coccidial diseases cause serious problems for Western Barn Owl (142). Chlamydia psittaci (parrot fever) was found in Western Barn Owl in Germany (143).Body ParasitesNo blood parasites were found in 62 Western Barn Owl (144). An intestinal trematode, Strigea strigis, was reported from Britain (65). The cestode Paruternia candelabraria was found in the intestines of birds in England (65).Subcutaneous mite (Tytodectes strigis) known from Western Barn Owl (145). Nestlings commonly and sometimes heavily infested by the dipteran Carnus hemapterus (146).'},
#  {'bird_name': 'Collared Inca',
#   'title': 'Self-Maintenance',
#   'text': 'Preening, Head-Scratching, Stretching, Sunbathing, Bathing, Anting, etc.Bird stretching (subspecies fulgidigula)Bird sunbathing (subspecies margaretae)Bird scratching and stretching (subspecies torquata)Bird preening (subspecies torquata)'},
#  {'bird_name': 'Raiatea Starling',
#   'title': 'Habitat',
#   'text': 'It was reported as occurring in valley thickets.'},
#  {'bird_name': 'Brown-cheeked Hornbill',
#   'title': 'Nonmigratory Movements',
#   'text': 'Is apparently nomadic during non-breeding season in Liberia, in flocks of up to 70, with occasional wandering reported in Ghana.'},
#  {'bird_name': 'Royal Spoonbill',
#   'title': 'Habitat in Breeding Range',
#   'text': 'Nesting in reedbeds, and on the ground and rocky headlands in New Zealand, is also reported.'},
#  {'bird_name': 'Western Barn Owl',
#   'title': 'Habitat in Nonbreeding Range',
#   'text': 'Habitat during the nonbreeding season generally similar to that in the breeding range.'},
#  {'bird_name': 'Meadow Pipit',
#   'title': 'Timing and Routes of Migration',
#   'text': 'Autumn migration predominantly in Sept–Nov; departure from wintering areas late Feb, main passage N through Europe in Mar–Apr. Vagrants recorded N to Spitsbergen, W to Madeira and Azores, and E to E Kazakhstan, N Pakistan and Oman; also as far from normal range as Japan.'},
#  {'bird_name': 'Common Gull',
#   'title': 'Migratory Behavior',
#   'text': 'No information.'},
#  {'bird_name': 'Western Barn Owl',
#   'title': 'Control and Physiology of Migration',
#   'text': 'Little information; see above. Food supply likely the ultimate and proximate factor triggering movements.'},
#  {'bird_name': 'Yellow Tyrannulet',
#   'title': 'Field Identification',
#   'text': '© Luke SeitzHeredia, Costa Rica 24 Mar 2017Macaulay Library ML 52419391eBirdS35404414'}]

# %%
def get_fact_node_counts():
    query = '''
    MATCH (f:Fact)
	WHERE NOT (f.title IN $titles_to_ignore)
	RETURN DISTINCT f.title AS fact_title, COUNT(*) AS cnt
    '''
    with graph.session(database=database) as session:
        records = session.run(
            query, 
			titles_to_ignore=[
				'About the Author(s)',
				'Acknowledgments',
				'Introduction',
				'Introduction?login'
			]
        )
        return [{ **r } for r in records]
    

fact_counts_df = pd.DataFrame(get_fact_node_counts())
fact_counts_df.head(5)
# Out:
#              fact_title   cnt
# 0        Identification  8248
# 1       Similar Species   360
# 2   Systematics History  8341
# 3  Geographic Variation   291
# 4            Subspecies  8391

# %%
import json
from openai import OpenAI
from tqdm.notebook import tqdm

from dotenv import load_dotenv

load_dotenv()

client = OpenAI()

single_facts = get_single_facts_by_title(10)

single_fact_sys_prompt = '''
You are a question & answer generator. Your job is to take a text input that represents a fact about a particular bird, and return a Q&A pair.
- Your input will be in the following JSON format: {
	"bird_name": "<<the bird's common name>>",
	"fact_title": "<<the title that describes what the fact is about",
	"text": "<<the text of the fact about that bird>>"
}
- You will output the following JSON: {
	"question": "<<A question that could be reliably answered, only using the information provided in the text>>",
	"answer": "<<The answer to that question, based only on the text provided>>"
}

Here is an example:
-- input: { "bird_name": "Ostrich", "fact_title": "Location", "text": "The Ostrich is the largest bird in Australia" }
-- output: { "question": "What is the largest bird in Australia?", "answer": "Ostrich" }

Follow these guidelines:
- Do not return a question that asks to describe the structure, layout, or any meta-information about the source material itself, e.g. "What sections are covered in the text?".
- While the question can be complex, keep the answer as brief as possible. In the answer, do not embellish, and only cover the points necessary to answer the question.
- Do not ask any open-ended questions that could be potentially have different answers than what is provided in the fact text, e.g. "What is a distinguishing feature of <<bird>>?".
- Do not provide an explanation, follow the structured output format exactly.
'''


def query_model(sys_prompt: str, user_prompt: str, model='gpt-4.1', temperature=0.5, max_output_tokens=300) -> str:
	resp = client.responses.create(
		model=model,
		instructions=sys_prompt,
		input=[
			{'role': 'user',   'content': [{'type': 'input_text', 'text': user_prompt}]},
		],
		temperature=temperature,
		max_output_tokens=max_output_tokens
	)

	return resp.output_text


def generate_basic_qa(sys_prompt: str, bird_row: dict[str, str]) -> dict[str, str]:
	user_prompt = json.dumps({
		'bird_name': bird_row['bird_name'], 
		'fact_title': bird_row['title'], 
		'text': bird_row['text']
	})

	response = query_model(sys_prompt, user_prompt)
	return json.loads(response)


single_fact_qas = []
for single_fact in tqdm(single_facts):
		qa = generate_basic_qa(single_fact_sys_prompt, single_fact)
		single_fact_qas.append(qa)

print(single_fact_qas[:5])
# Out:
#   0%|          | 0/681 [00:00<?, ?it/s]
# [{'question': 'What distinguishes the Boat-billed Heron from Nycticorax nycticorax?', 'answer': 'The Boat-billed Heron is overall much whiter in appearance and has an incredibly broad, flattened and thick bill.'}, {'question': 'How can the Plain Prinia be distinguished from P. sylvatica?', 'answer': 'By its smaller size, less bulky appearance, narrower-based tail, weaker legs, smaller bill, more prominent supercilium, and lack of dark mottling on the lower malar region.'}, {'question': "What is a distinguishing feature of Monteiro's Bushshrike compared to M. blanchoti?", 'answer': 'It has dark grey eyes (not yellow) and a more extensive pale face patch.'}, {'question': 'What are the key identification features of the Western Olivaceous Flatbill?', 'answer': 'Large-headed, dark-olive flatbill with white eyering, dusky wings with yellow-edged coverts and secondaries, yellow-edged tertials, dusky tail with pale margins, pale gray or yellow throat, grayish olive breast, pale yellow belly and flanks, olive-streaked breast and flanks, brown to black iris, very wide and flat bill with black maxilla and pale mandible, blue gray legs; sexes similar; juveniles are duller olive above and paler yellow below.'}, {'question': 'What are some distinguishing features of the European Honey-buzzard compared to true buzzards of genus Buteo?', 'answer': 'The European Honey-buzzard differs from true buzzards of genus Buteo by having a small head, slender bill, thin neck, longer tail, and yellow iris.'}]

# %%
import pandas as pd

qa_df = pd.DataFrame({
	'question': [ qa['question'] for qa in single_fact_qas ],
	'answer':  [ qa['answer'] for qa in single_fact_qas ],
	'qa_type': 'single_fact',
	'ground_truth': single_facts
})

display(qa_df.head(5))
qa_df.to_csv('../data/eval_qas.csv')
# Out:
#                                             question  \
# 0  What distinguishes the Boat-billed Heron from ...
# 1  How can the Plain Prinia be distinguished from...
# 2  What is a distinguishing feature of Monteiro's...
# 3  What are the key identification features of th...
# 4  What are some distinguishing features of the E...
#
#                                               answer      qa_type  \
# 0  The Boat-billed Heron is overall much whiter i...  single_fact
# 1  By its smaller size, less bulky appearance, na...  single_fact
# 2  It has dark grey eyes (not yellow) and a more ...  single_fact
# 3  Large-headed, dark-olive flatbill with white e...  single_fact
# 4  The European Honey-buzzard differs from true b...  single_fact
#
#                                         ground_truth
# 0  {'bird_name': 'Boat-billed Heron', 'title': 'I...
# 1  {'bird_name': 'Plain Prinia', 'title': 'Identi...
# 2  {'bird_name': 'Monteiro's Bushshrike', 'title'...
# 3  {'bird_name': 'Western Olivaceous Flatbill', '...
# 4  {'bird_name': 'European Honey-buzzard', 'title...

# %%
compare_sample_size = 20

facts_for_compare_df = pd.DataFrame(get_single_facts_by_title(compare_sample_size))

compare_w_counts = facts_for_compare_df.merge(fact_counts_df, left_on='title', right_on='fact_title', how='left')
facts_for_compare_df = compare_w_counts[compare_w_counts.cnt > compare_sample_size].drop(columns=['fact_title', 'cnt'])

print(len(facts_for_compare_df))
facts_for_compare_df.head(5)
# Out:
# 1180
#                    bird_name           title  \
# 0      Mindanao Cuckooshrike  Identification
# 1  Chestnut-rumped Heathwren  Identification
# 2          Striated Softtail  Identification
# 3         Victorin's Warbler  Identification
# 4         Collared Scops-Owl  Identification
#
#                                                 text
# 0  ~26.6 cm (1). Male is gray on head and upperpa...
# 1  12·5–16 cm; 17 g. A terrestrial acanthizid wit...
# 2  17–18 cm. Small furnariid with shape like Cran...
# 3  15–17 cm; 10 g. A short-winged warbler with lo...
# 4  The Collared Scops-Owl occurs in grayish brown...

# %%
def fact_compare(fact_texts: list[dict[str, str]], p=3) -> dict[str, str]:
	comparison_sys_prompt = f'''
You are a question & answer generator. Your job is to take a text input that represents a series of facts about birds, and return a series of {p} Q&A pairs that can only be answered with those facts.
The facts could be about the same bird, or different birds. Each fact has a "fact_title" key, which describes what the fact is about, e.g. "Breeding".

- Your input will be an array in the following JSON format: [{{
	"bird_name": "<<the bird's common name>>",
	"fact_title": "<<the title that describes what the fact is about",
	"text": "<<the text of the fact about that bird>>"
}}, {{ "bird_name": "...", "fact_title": "...", "text": "..." }}, ... ]

- You will output the following JSON: {{
	"question": "<<A question that could be reliably answered using only the information provided in the text>>",
	"answer": "<<The answer to that question, based only on the text provided>>"
}}

Here is an example:
-- input: [
	{{ "bird_name": "Ostrich", "fact_title": "Location", "text": "The Ostrich is the largest bird in Australia" }},
	{{ "bird_name": "Dodo", "fact_title": "Conservation Status", "text": "The Dodo is extinct, formerly the largest bird in Australia" }}
]
-- output: [
    {{ "question": "Which one is currently the largest bird in Australia, the Ostrich or the Dodo?", "answer": "Ostrich" }}
	...{p-1} more entries
]

Follow these guidelines:
- Do not return questions that ask to describe the structure, layout, or any meta-information about the source material itself, e.g. "What sections are covered in the text?" would be incorrect.
- While the question can be complex, keep the answers as brief as possible. In the answer, do not embellish, and only cover the points necessary to answer each question.
- Do not ask any questions that are too vague, and could have a different answer if new information was provided. e.g. "Which bird is blue?" would be too vague.
- Make sure you incorporate information from all of the facts in your response, a good Q&A pair should only be answerable with each fact provided.
- Make sure you output {p} Q&A pairs, following the structured output format exactly, in valid JSON. Do not provide any explanations.
'''

	response = query_model(comparison_sys_prompt, json.dumps(fact_texts), temperature=0.5)
	return json.loads(response)

#- Do not ask any open-ended questions that could be potentially have different answers than what is provided in the fact text, e.g. "What is a distinguishing feature of <<bird>>?".
#- In your answer, refer to any birds by name, DO NOT implicitly refer to any bird facts, e.g. "the first bird has a..." would be an example of an INCORRECT answer.

fact_1 = facts_for_compare_df.iloc[2]
print(fact_1.bird_name, fact_1.title, fact_1.text)
fact_2 = facts_for_compare_df.iloc[5]
print(fact_2.bird_name, fact_2.title, fact_2.text)
fact_3 = facts_for_compare_df.iloc[10]
print(fact_3.bird_name, fact_3.title, fact_3.text)

fact_compare([
	{ 'bird_name': fact_1.bird_name, 'fact_title': fact_1.title, 'text': fact_1.text },
	{ 'bird_name': fact_2.bird_name, 'fact_title': fact_2.title, 'text': fact_2.text },
	{ 'bird_name': fact_3.bird_name, 'fact_title': fact_3.title, 'text': fact_3.text },
])
# Out:
# Striated Softtail Identification 17–18 cm. Small furnariid with shape like Cranioleuca but patterned more like Asthenes. Has indistinct buff supercilium, pale lores, rest of face brownish with broad pale buff to tawny-buff streaks; crown and upper­parts dark reddish-brown with conspicuous brown-bordered reddish-rufous to rufous buff shaft streaks; wings mostly dark rufous, remiges with dark fuscous tips; tail graduated, rectrices with shafts slightly stiffened basally, tips blunt, pale tawny to cinnamon-rufous; chin and upper throat orange-rufous to yellowish-orange; underparts dull brown, streaked buff, streaks fading on belly and undertail-coverts; iris deep chestnut brown; upper mandible dusky horn to silvery grey, lower mandible bluish-grey with dusky horn tip; tarsus and toes dull greenish-grey. Sexes alike. Juvenile lacks throat patch, has less well-defined streaks on back, is more mottled than streaked below.
# Philippine Scops-Owl Identification 23–28 cm; c. 200–310 g (1). With O. sagittatus, the largest of the Old World scops-owls. Occurs in grey-brown and rufous morphs. Grey-brown morph deep brown or brownish-olive above with buff vermiculations, black-tipped pale feathers on hindneck forming collar, whitish eyebrows, underparts buffish-grey with some broad black shaft markings and few thin cross-lines; rufous morph brownish-red above, generally buffy-yellow below; both morphs with barred wings and tail; tarsus feathered to toes; iris golden-brown or orange-brown; bill light brown, tipped with white; feet dull white to yellow-brown. Differentiated from O. bakkamoena by comparatively larger size. Juvenile similar to respective adult morph but more barred; rufous morph juvenile more deeply cinnamon than adult. O. longicornis, the only other scops-owl on Luzon, much smaller than present species, has more brightly coloured irides and usually occurs at higher elevations (2).
# Ornate Lorikeet Identification 25 cm. Bill orange-red; crown and ear coverts purplish black; face and postocular stripe red; side of neck yellow; throat and breast red broadly barred deep blue; belly green with some yellow edges, becoming regular on thighs and below; hindneck to tail green; wings with yellow leading edge and underwing coverts yellow; tail below dull yellow. Immature has brownish bill and more yellow on belly.
# [{'question': 'Which bird among the Striated Softtail, Philippine Scops-Owl, and Ornate Lorikeet has the largest size according to the identification facts provided?',
#   'answer': 'Philippine Scops-Owl'},
#  {'question': 'Which bird is described as having a throat and breast that are red broadly barred with deep blue?',
#   'answer': 'Ornate Lorikeet'},
#  {'question': "Which bird's juvenile lacks a throat patch and has less well-defined streaks on the back compared to the adult?",
#   'answer': 'Striated Softtail'}]

# %%
import itertools as it

def get_combinations(df: pd.DataFrame, k: int, num_samples: int, group_col='title') -> tuple[pd.Series]:
	def tuples_for_col(group):
		tuples = []
		for perm in it.islice(it.permutations(group.index, k), num_samples):
			tuples.append(tuple(group.loc[idx] for idx in perm))
		return tuples

	return (
		df.groupby(group_col, group_keys=False)
				.apply(tuples_for_col)
	)


comparison_samples = get_combinations(facts_for_compare_df, 2, 5)
print(len(comparison_samples), len(comparison_samples[0]), len(comparison_samples[0][0]))
print('NUM SAMPLES:', len(comparison_samples)*len(comparison_samples[0]))
[ samp.to_dict() for samp in comparison_samples[0][0] ]
# Out:
# 59 5 2
# NUM SAMPLES: 295
# /tmp/ipykernel_1454209/246556492.py:12: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(tuples_for_col)
# /tmp/ipykernel_1454209/246556492.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(len(comparison_samples), len(comparison_samples[0]), len(comparison_samples[0][0]))
# /tmp/ipykernel_1454209/246556492.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('NUM SAMPLES:', len(comparison_samples)*len(comparison_samples[0]))
# /tmp/ipykernel_1454209/246556492.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   [ samp.to_dict() for samp in comparison_samples[0][0] ]
# [{'bird_name': 'Giant Coot',
#   'title': 'Agonistic Behavior',
#   'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'},
#  {'bird_name': 'Sula Lorikeet',
#   'title': 'Agonistic Behavior',
#   'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}]

# %%
from tqdm.notebook import tqdm
from json import JSONDecodeError

hop_2_samples = get_combinations(facts_for_compare_df, 2, 5)
hop_3_samples = get_combinations(facts_for_compare_df, 3, 5)
hop_4_samples = get_combinations(facts_for_compare_df, 4, 5)


def get_qas_for_comparison(samples: list[list[tuple[str, str]]], p=3) -> pd.DataFrame:
	all_qas = []
	for title_division in tqdm(samples):
		for sample in title_division:
			qa_input = [ fact.to_dict() for fact in sample ]	
			retries = 3
			trying = True
			while retries > 0 and trying:
				try:
					qas = fact_compare(qa_input, p=p)
					for qa in qas:
						all_qas.append({ **qa, 'ground_truth': [ s.to_dict() for s in sample ]})
					trying = False
				except JSONDecodeError:
					print('JSON parsing failed, retrying...')
					retries -= 1
			if retries == 0:
				raise Exception(f'JSON parsing failed 3 times')
			
	return pd.DataFrame(all_qas)

print('GETTING 2 HOP SAMPLES...')
hop_2_df = get_qas_for_comparison(hop_2_samples)
hop_2_df['qa_type'] = '2_hop'
print(f'FETCHED {len(hop_2_df)} 2 HOP SAMPLES')
print('GETTING 3 HOP SAMPLES...')
hop_3_df = get_qas_for_comparison(hop_3_samples)
hop_3_df['qa_type'] = '3_hop'
print(f'FETCHED {len(hop_3_df)} 3 HOP SAMPLES')
print('GETTING 4 HOP SAMPLES...')
hop_4_df = get_qas_for_comparison(hop_4_samples)
hop_4_df['qa_type'] = '4_hop'
print(f'FETCHED {len(hop_4_df)} 4 HOP SAMPLES')
# Out:
# GETTING 2 HOP SAMPLES...
# /tmp/ipykernel_1454209/246556492.py:12: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(tuples_for_col)
# /tmp/ipykernel_1454209/246556492.py:12: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(tuples_for_col)
# /tmp/ipykernel_1454209/246556492.py:12: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(tuples_for_col)
#   0%|          | 0/59 [00:00<?, ?it/s]
# JSON parsing failed, retrying...
# JSON parsing failed, retrying...
# FETCHED 885 2 HOP SAMPLES
# GETTING 3 HOP SAMPLES...
#   0%|          | 0/59 [00:00<?, ?it/s]
# JSON parsing failed, retrying...
# FETCHED 885 3 HOP SAMPLES
# GETTING 4 HOP SAMPLES...
#   0%|          | 0/59 [00:00<?, ?it/s]
# JSON parsing failed, retrying...
# JSON parsing failed, retrying...
# FETCHED 885 4 HOP SAMPLES

# %%
import pandas as pd

eval_qas = pd.read_csv('../data/eval_qas.csv', index_col=0)
print(f'OLD EVAL QAS LENGTH: {len(eval_qas)}')
eval_qas = pd.concat([eval_qas, hop_2_df, hop_3_df, hop_4_df], ignore_index=True)
print(f'NEW QAS LENGTH WITH NEW DATA: {len(eval_qas)}')
eval_qas.to_csv('../data/eval_qas_with_hops.csv')
# Out:
# OLD EVAL QAS LENGTH: 681
# NEW QAS LENGTH WITH NEW DATA: 3336

# %%
import os
from neo4j import GraphDatabase
from dotenv import load_dotenv

load_dotenv()

graph = GraphDatabase.driver(
    os.environ['NEO4J_URI'],
    auth=(os.environ['NEO4J_USER'], os.environ['NEO4J_PWD'])
)
database = os.environ['NEO4J_DATABASE']


def vertex_sampling_w_contraction(N: int):
    with graph.session(database=database) as session:

        def start_node():
            rec = session.run('''
                MATCH (n)
                WHERE NOT n:Reference
                RETURN elementId(n) AS id
                ORDER BY rand()
                LIMIT 1    
            ''').single()
            return rec['id']

        def contract_neighborhood(in_neighborhood: set[str]):
            recs = session.run('''
                MATCH (base)-[]-(neighbor)
                WHERE 
                    elementId(base) IN $n_ids
                    AND NOT elementId(neighbor) IN $n_ids
                    AND NOT base:Reference
                    AND NOT neighbor:Reference
				WITH DISTINCT labels(neighbor)[0] AS neighbor_label, collect(neighbor) AS nodes_in_label
				WITH collect({label: neighbor_label, nodes: nodes_in_label}) AS label_groups
				WITH label_groups[toInteger(rand() * size(label_groups))] AS chosen_group
				WITH chosen_group.nodes AS nodes_in_chosen_label
				WITH nodes_in_chosen_label[toInteger(rand() * size(nodes_in_chosen_label))] AS picked_neighbor
				RETURN elementId(picked_neighbor) AS id
            ''', n_ids=list(in_neighborhood)).value()
            return recs[0] if recs else None
        '''
                RETURN elementId(nbr) AS id
                ORDER BY rand()
                LIMIT 1
			'''

        def fetch_nodes(ids: set[str]):
            result = session.run('''
                MATCH (n)
                WHERE elementId(n) IN $ids
                RETURN elementId(n) AS id, labels(n) AS labels, n AS node
            ''', ids=list(ids))
            nodes = []
            for record in result:
                props = dict(record["node"])
                props["node_label"] = record["labels"][0] if record["labels"] else None
                nodes.append(props)
            return nodes

        sampled = set([start_node()])
        num_sampled = 1

        while num_sampled < N:
            nxt = contract_neighborhood(sampled)
            if nxt is None:
                break
            sampled.add(nxt)
            num_sampled += 1

        return fetch_nodes(sampled)

[ samp['node_label'] for samp in vertex_sampling_w_contraction(20)]
# Out:
# ['Image',
#  'Family',
#  'Image',
#  'Bird',
#  'Genus',
#  'Fact',
#  'Bird',
#  'Fact',
#  'Bird',
#  'Bird',
#  'Fact',
#  'Image',
#  'Bird',
#  'Family',
#  'Bird',
#  'Image',
#  'Bird',
#  'Order',
#  'Genus',
#  'Image']

# %%
import json
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

client = OpenAI()


def serialize_node(node: dict[str, str]) -> dict:
	if node['node_label'] == 'Bird':
		content = [{
			'type': 'input_text',
			'text': json.dumps({
				'node_label': node['node_label'],
				'name': node['name'],
				'order': node['order'],
				'family': node['family'],
				'genus': node['genus'],
				'species': node['species']
			}) 
		}]
	elif node['node_label'] == 'Fact':
		content = [{
			'type': 'input_text',
			'text': json.dumps({
				'node_label': node['node_label'],
				'bird_name': node['bird_name'],
				'fact_title': node['title'],
				'content': node['text']
			})
		}]
	elif node['node_label'] == 'Image':
		content = [
			{
				'type': 'input_image',
				'image_url': node['url']
			},
			{
				'type': 'input_text',
				'text': json.dumps({
					'node_label': node['node_label'],
					'bird_name': node['bird_name'],
					**({'title': node['title']} if node['title'] else {})
				})
			}
		]
	elif node['node_label'] in ['Genus', 'Family', 'Order']:
		content = [{
			'type': 'input_text',
			'text': json.dumps({
				'node_label': node['node_label'],
				'name': node['name']	
			})
		}]

	return {
		'role': 'user',
		'content': content
	}
				

def synthesize_qas_from_neighborhood(
    num_qas: int, 
    num_in_neighborhood: int,
	model='gpt-4.1',
	temperature=0.5
) -> list[dict[str, str]]:

	neighborhood_prompt = f'''
You are a question & answer generator. Your job is to accept a series of TEXT and IMAGE inputs, and use them to construct a series of Q&A pairs.
All inputs represent facts, images, or properties of birds, and are represented as JSON objects. Each input is derived from a graph, where this data is stored.
Each image input will additionally be followed by a JSON object as a caption, containing the metadata information for that image in the database. Use BOTH the image and its metadata when creating the Q&A pairs.
Each input will have a "node_label" key, which describes what the node represents.

Follow these steps when generating your Q&A pairs:
1. First, mentally analyze each input separately and extract its key ideas. For images, describe as many details about each image as possible.
2. Then, synthesize all of the ideas into {num_qas} questions that could be answered using ONLY the inputs as reference.
-- DO NOT ask any questions that are too vague, and could have a different answer if new information was available. e.g. "Which bird is blue?" would be INCORRECT.
-- Every question MUST incorporate information from AS MANY inputs as possible. DO NOT just regurgitate information from one node.
-- Each question should be unique from each other, and EVERY input should be represented at some point.
3. Then, using the inputs as reference, answer each question.
-- Each answer should be as brief as possible. Do not embellish. Only cover the relevant points. 
4. Respond ONLY as JSON with the shape: {{ "qas": [{{ "question": "...", "answer": "..." }}, {{ "question": "...", "answer": "..." }}, ...] }}
-- Make sure you output {num_qas} Q&A pairs, following the structured output format exactly, in valid JSON. Do not provide any explanations.

MAKE SURE THAT THE QUESTIONS DO NOT DIRECTLY REFERENCE THE TEXT OR CONTENT. Here are some examples of INCORRECT questions:
-- "...In the image shown..."
-- "...For the birds provided..."
-- "...In the reference text..."
-- "...as evidenced by what is listed..."
THE QUESTIONS SHOULD BE ABLE TO BE ASKED WITHOUT ANY KNOWLEDGE OF THE REFERENCE INFORMATION.
'''

	samples = vertex_sampling_w_contraction(num_in_neighborhood)
	serialized_samples = [ serialize_node(node) for node in samples ]

	resp = client.responses.create(
		model=model,
		instructions=neighborhood_prompt,
		input=serialized_samples,
		text={
      		'format': {
				'type': 'json_schema',
				'name': 'qa_array',
				'strict': True,
				'schema': {
					'type': 'object',
					'properties': {
						'qas': {
							'type': 'array',
							'minItems': num_qas,
							'maxItems': num_qas,
							'items': {
								'type': 'object',
								'properties': {
									'question': {'type': 'string'},
									'answer': {'type': 'string'}
								},
								'required': ['question', 'answer'],
								'additionalProperties': False
							}
						}
					},
					'required': ['qas'],
					'additionalProperties': False	
				}
			}
        }
	)

	return json.loads(resp.output_text)['qas'], serialized_samples


sample_vsc_qas, sample_vsc_ground_truth = synthesize_qas_from_neighborhood(
	num_qas=10,
	num_in_neighborhood=30,
	model='gpt-4.1'
)

for ind, ground_truth in enumerate(sample_vsc_ground_truth):
	print(f'NODE {ind}: ', ground_truth)

for ind, qa in enumerate(sample_vsc_qas):
	print(f'QA {ind}: ', qa)
# Out:
# NODE 0:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Genus", "name": "Ptychoramphus"}'}]}
# NODE 1:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Bird", "name": "Peruvian Tern", "order": "Charadriiformes", "family": "Laridae", "genus": "Sternula", "species": "Lorata"}'}]}
# NODE 2:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Order", "name": "Charadriiformes"}'}]}
# NODE 3:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Fact", "bird_name": "Hudsonian Godwit", "fact_title": "Introduction", "content": "The Hudsonian Godwit (Limosa haemastica), known in the past as the Ring-tailed Marlin or Goose-bird, is the least well known of the world\'s four godwit species. With the majority of its population restricted to only a few remote sites during much of the year, it was long regarded as one of the rarest birds on the continent, ranked with the likes of the Kirtland\'s Warbler (Setophaga kirtlandii) and Bachman\'s Warbler (Vermivora bachmanii) by the American Ornithologists\' Union\'s Committee on Bird Protection (1). Starting in the 1940s, however, biologists began to discover large migratory flocks at remote sites along the shores of James and Hudson Bays, leading to the realization that the status of the species was not as dire as it had seemed. More recently, additional fall staging sites have been found in Saskatchewan, along with major wintering areas in southern South America. The species is, nonetheless, highly vulnerable, with a population of between 50,000\\u201370,000 birds, the majority of which occur at only a handful of sites during the nonbreeding season.Although historically the biology of this godwit has been poorly known, that is beginning to change. Known breeding areas still account for only a small proportion of the estimated world population, however, and much of the breeding range clearly remains to be described. Those breeding areas that are known are disjunct, and studies by Susan Haig and colleagues suggest that different populations are as distinct genetically as those of any other bird species. This result is especially surprising given that no plumage or structural differences have been described. However, breeding habitat does vary greatly among sites, although it frequently consists of sedge meadows and muskeg at the tree line in Canada and Alaska, often near coastal mudflats or major river systems.The most detailed study of breeding biology was conducted by J. A. Hagar (2) at Churchill, Manitoba; this remains the benchmark description of the biology of the species. Additional work in that region, by J. R. Jehl, Jr., Joanna Klima, and colleagues, has also been pivotal in furthering our understanding of the species. In Alaska, Williamson and Smith (3) studied the Hudsonian Godwits in the vicinity of Cook Inlet, and a number of biologists elsewhere in the state have continued to find new breeding areas well into the 2000\'s. Work begun at both Churchill and Cook Inlet will try to build on these seminal studies and to further our understanding of this species\' breeding biology.After breeding, the Hudsonian Godwit undertakes a migration from the subarctic to southern South America, in which they make nonstop flights of several thousand miles. During the migration period, this species is found in various fresh-water and saline habitats. Its diet is not well known, but studies by Stuart Alexander and Cheri Gratto-Trevor have shown that migrating birds rely heavily on plant tubers at some inland staging sites (4, 5, 6); at other times, various invertebrates are taken.Nonbreeding Hudsonian Godwits concentrate at sites with large expanses of coastal mudflats. Increasingly, South American biologists are studying the biology of this species away from the breeding grounds. Detailed research at major nonbreeding sites has been initiated in Argentina and Chile and will be especially important for the future conservation of the species."}'}]}
# NODE 4:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/40539711/640'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Cassin\'s Auklet", "title": "Adult Small, chunky dark gray seabird with light gray flanks. "}'}]}
# NODE 5:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Fact", "bird_name": "Cassin\'s Auklet", "fact_title": "Introduction", "content": "One of the most widely distributed of the Pacific alcids, and among auklets one of the best studied, Cassin\'s Auklet is an island-breeding species found from the Kurile Islands (Russia/Japan) through the Alaskan Aleutians and south to Baja California. The center of breeding is along the coast of British Columbia.This small, abundant auklet nests in shallow burrows, which the birds excavate with their sharp toe nails, and also in rock crevices or under trees, cacti or logs. During the nonbreeding season, this species spends most of its time at sea, with southern populations likely moving north and northern ones moving south to the central portion of its eastern Pacific range; it is most abundant in waters overlying the continental shelf and slope where its preferred food includes small crustaceans, squid, and larval/juvenile fish. Where such prey are abundant, these birds often gather in large flocks, diving after prey propelled by their short, stubby wings. They gather their food and transport it back to the nest in a specialized throat pouch, a structure common to all true auklets.The timing of Cassin\'s Auklet breeding varies with latitude and year. Birds nest in late fall through winter in Baja California, but in early to mid-summer in Alaska. Laying is late during El Ni\\u00f1o and like oceanographically anomalous years, and early when upwelling occurs early. This is the only alcid known to produce two consecutive broods in a single breeding season, at least in the southern part of the range where birds may be seen at nesting colonies year round. Vulnerable to aerial predators, especially large gulls and falcons, individuals fly between sea and colonies at night.Breeding biology is well known in this auklet, spanning the species\' southern and central range, with major studies from the San Benito Is., Mexico; the Farallon Is., CA; and Triangle Is., BC, but little is known elsewhere (e.g. Manuwal 1974a, b, 1979; Vermeer 1987; Ainley et al.1990; Knechtel 1998; Hedd et al. 2002; Hipfner et al. 2004; Lee et al. 2007; Wolf 2007, Wolf et al. 2009, 2010). Key studies of auklets at sea include Abraham and Sydeman 2004, 2006; Adams et al. 2004a,b, 2010; Ainley et al. 1996, 2005, 2009; Ainley and Hyrenbach 2009; Boyd et al. 2008; Hyrenbach and Veit 2003; Lee et al. 2007. Conservation issues have been covered by Burger (1997), Everett and Anderson (1991), McChesney and Tershy (1998), and Wolf et al. 2006)."}'}]}
# NODE 6:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Family", "name": "Alcidae"}'}]}
# NODE 7:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/162039371/640'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Hudsonian Godwit", "title": "Adult male Hudsonian Godwit. Bill color varies by age, sex, and season. When breeding, pale basal area increases to occupy 50\\u201360% of bill, and during the courtship period, it is brighter pinkish orange in males but then fades rapidly to a duller more purplish-pink color of adult females. The base also becomes duller during the molt and winter periods. The iris (concealed by the nictitating membrane here) is sepia or dark brown at all ages. "}'}]}
# NODE 8:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Family", "name": "Scolopacidae"}'}]}
# NODE 9:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Family", "name": "Laridae"}'}]}
# NODE 10:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/24955551/640'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Cassin\'s Auklet", "title": "Cassin\'s Auklet chick, Farallon Islands, CA, June. Cassin\'s Auklets nest in burrows as well as in man-made nest boxes. The following is a link to this photographer\'s website: http://www.flickr.com/photos/15050719@N03/"}'}]}
# NODE 11:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/24957011/640'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Cassin\'s Auklet", "title": "Adult Cassin\'s Auklet in pelagic habitat, Monterey Bay, CA, August. Cassin\'s Auklets forage in offshore waters, and often congregate in areas with active krill blooms and strong upwelling. They can occur singly or in loosely packed groups, the latter probably more a result of birds converging on an abundant food source rather than truly gregarious at-sea behavior. They can be a challenge to see on the water, being small, dark, and prone to dive or fly off as the boat approaches."}'}]}
# NODE 12:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Genus", "name": "Limosa"}'}]}
# NODE 13:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Fact", "bird_name": "Pantanal Snipe", "fact_title": "Movements and Migration", "content": "Essentially sedentary, in some areas performing short seasonal movements to permanent marshland during austral winter, when this or Magellanic Snipe G. magellanica reaches E Amazonian Brazil (4). Record from NW coast of Peru has been tentatively ascribed to paraguaiae, but might easily have involved vagrant G. delicata (which species has recently been recorded in Ecuador)."}'}]}
# NODE 14:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/24915191/640'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Cassin\'s Auklet", "title": "Adult Cassin\'s Auklet, Farallon Islands, CA, 9 October. Cassin\'s Auklets nest mainly in burrows on oceanic islands. They are primarily nocturnal around the colony, thereby avoiding predation by gulls and raptors. The following is a link to this photographer\'s website: http://www.flickr.com/photos/henicorhina/"}'}]}
# NODE 15:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Genus", "name": "Gallinago"}'}]}
# NODE 16:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/239474271/640'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Hudsonian Godwit", "title": "Hudsonian Godwit. "}'}]}
# NODE 17:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/573458321/320'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Hudsonian Godwit", "title": "Enlarge Year-round Migration Breeding Non-Breeding Distribution of the Hudsonian Godwit"}'}]}
# NODE 18:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Bird", "name": "Hudsonian Godwit", "order": "Charadriiformes", "family": "Scolopacidae", "genus": "Limosa", "species": "Haemastica"}'}]}
# NODE 19:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Bird", "name": "Painted Buttonquail", "order": "Charadriiformes", "family": "Turnicidae", "genus": "Turnix", "species": "Varius"}'}]}
# NODE 20:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/309955141/640'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Peruvian Tern", "title": "Juvenile Peruvian Tern. The upperpart feathers and upperwing coverts are beige with bold black chevrons on lesser coverts and tips to gray-based greater coverts. Some juveniles can have brighter yellow-orange lower mandibles and legs. "}'}]}
# NODE 21:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Genus", "name": "Sternula"}'}]}
# NODE 22:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Bird", "name": "Black-tailed Godwit", "order": "Charadriiformes", "family": "Scolopacidae", "genus": "Limosa", "species": "Limosa"}'}]}
# NODE 23:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/32007461/320'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Cassin\'s Auklet", "title": "Enlarge Year-round Migration Breeding Non-Breeding Figure 1. Breeding and year-round range of Cassin\'s Auklet. Southern populations appear to be sedentary, northern populations migratory, but data are needed to clarify movements."}'}]}
# NODE 24:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Bird", "name": "Pantanal Snipe", "order": "Charadriiformes", "family": "Scolopacidae", "genus": "Gallinago", "species": "Paraguaiae"}'}]}
# NODE 25:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/522788221/480'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Cassin\'s Auklet"}'}]}
# NODE 26:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Fact", "bird_name": "Pantanal Snipe", "fact_title": "Identification", "content": "26\\u201330 cm; male 106\\u2013139 g, female 113\\u2013182\\u00b79 g (1). Small snipe , very similar to G. magellanicus, G. andina, G. gallinago, and G. nigripennis. Female very similar to male, but slightly larger. Like these species, it is a stout, deep-bodied shorebird with a square head in which eyes are set far back, a short neck, a very long straight thick bill, and short legs. No seasonal variation. Juvenile very similar to adult, but wing-coverts more neatly fringed pale buff.Lateral view.Lateral view, showing underwing.Lateral view.Dorsal view.Frontal view.Ventral view."}'}]}
# NODE 27:  {'role': 'user', 'content': [{'type': 'input_image', 'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/439575581/480'}, {'type': 'input_text', 'text': '{"node_label": "Image", "bird_name": "Hudsonian Godwit"}'}]}
# NODE 28:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Bird", "name": "Cassin\'s Auklet", "order": "Charadriiformes", "family": "Alcidae", "genus": "Ptychoramphus", "species": "Aleuticus"}'}]}
# NODE 29:  {'role': 'user', 'content': [{'type': 'input_text', 'text': '{"node_label": "Fact", "bird_name": "Pantanal Snipe", "fact_title": "Breeding", "content": "Eggs found in May in Uruguay (though considered atypical), May\\u2013Oct on Trinidad, while display flights are given intensely in May\\u2013Sept (early and mid wet season) in Venezuelan llanos (2) (although this may not be a good indicator of breeding as such flights are recorded year-round in southernmost Brazil, where eggs and small young recorded in Feb, Jun, Aug and Sept) (6). Typically lays four eggs (7). The following information refers either to G. paraguaiae or to G. magellanica, or both: colour cream to greyish yellow with brownish-grey to grey markings especially at larger end, size 38\\u00b77\\u201342\\u00b75 mm \\u00d7 27\\u00b77\\u201332\\u00b75 mm (7). Downy chick is dark chestnut, with complex pattern of white bands outlined in black over head, neck and breast, and tiny but densely packed white powder-puffs. No further information, e.g. on incubation or fledging periods.Nest; general view.Nest with three eggs.Three eggs.Adult incubating.Downy chick.Adult with downy chick."}'}]}
# QA 0:  {'question': 'Which genus includes a seabird species that breeds on islands from the Kurile Islands to Baja California, constructs burrows for nesting, and is classified in the family Alcidae?', 'answer': "Ptychoramphus includes a seabird species with these characteristics, specifically Cassin's Auklet."}
# QA 1:  {'question': 'What bird in the family Scolopacidae breeds in remote northern regions and migrates to southern South America, with evidence of genetic divergence among populations but no noticeable plumage differences?', 'answer': 'The Hudsonian Godwit (Limosa haemastica) displays these traits.'}
# QA 2:  {'question': 'Which Charadriiformes genus includes a species whose juveniles have beige upperparts with black chevrons, brighter yellow-orange mandibles and legs, and is in the family Laridae?', 'answer': 'Sternula includes such a species, specifically the Peruvian Tern.'}
# QA 3:  {'question': 'What shorebird in the genus Gallinago is essentially sedentary but makes short seasonal movements to permanent marshlands during the austral winter, and females are slightly larger than males?', 'answer': 'The Pantanal Snipe fits this description.'}
# QA 4:  {'question': 'Which auklet species can be identified by its small, chunky, dark gray body, light gray flanks, and is most abundant over the continental shelf and slope where it dives for crustaceans and fish?', 'answer': "Cassin's Auklet matches these identification traits."}
# QA 5:  {'question': 'Which species is the only alcid known to produce two consecutive broods in a single breeding season, at least in the southern part of its range where it may nest year round?', 'answer': "Cassin's Auklet is the only alcid known for this reproductive strategy."}
# QA 6:  {'question': 'What snipe, similar in build and appearance to G. magellanicus and G. gallinago, lays typically four eggs with cream to greyish yellow color marked brownish-grey, and has a downy chick that is dark chestnut with white bands outlined in black?', 'answer': 'The Pantanal Snipe (Gallinago paraguaiae) exhibits these reproductive and chick plumage characteristics.'}
# QA 7:  {'question': 'Which godwit species has a breeding range in Alaska and Canada, undertakes long-distance nonstop migrations, and is mainly found during nonbreeding at only a few sites where it relies on plant tubers and invertebrates for food?', 'answer': 'Hudsonian Godwit fits these migration and feeding descriptions.'}
# QA 8:  {'question': 'What bird in the order Charadriiformes, family Alcidae, and genus Ptychoramphus, is best studied among auklets and nests in either burrows or under debris such as trees or logs?', 'answer': "Cassin's Auklet is the bird fitting this description."}
# QA 9:  {'question': 'Which member of the genus Limosa and family Scolopacidae is well studied at sites like Churchill, Manitoba and Cook Inlet, Alaska, and is vulnerable due to most of its nonbreeding population being at only a few sites?', 'answer': 'The Hudsonian Godwit (Limosa haemastica) is the species described here.'}

# %%
import time
import openai
import threading
from tqdm.notebook import tqdm

num_total_rows = 3000
num_workers = 4
num_qas_per_query = 10

if 'vsc_qa_rows' in locals():
    print(f'{len(vsc_qa_rows)} rows already parsed')
    print(f'parsing {num_total_rows - len(vsc_qa_rows)}')
else:
    vsc_qa_rows = []

lock = threading.Lock()

def qa_vsc_gen_worker(thread_id):
	for _ in tqdm(range(int((num_total_rows - len(vsc_qa_rows)) / (num_workers * num_qas_per_query)))):
		retries = 3
		done = False
		while retries > 0 and not done:
			try:
				vsc_qas, vsc_ground_truth = synthesize_qas_from_neighborhood(
					num_qas=num_qas_per_query,
					num_in_neighborhood=30,
					model='gpt-4.1'
				)
				with lock:
					for vsc_qa in vsc_qas:
						vsc_qa_rows.append(vsc_qa | {
							'ground_truth': vsc_ground_truth,
							'qa_type': 'vsc_neighborhood'
						})
				done = True
			except openai.RateLimitError:
				print(f'Hit rate limit, retrying...({retries} left)')
				time.sleep(10)
				retries -= 1

threads = [
	threading.Thread(target=qa_vsc_gen_worker, args=(tid, ))
	for tid in range(num_workers)
]

for t in threads:
    t.start()
for t in threads:
    t.join()

len(vsc_qa_rows)
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]
#   0%|          | 0/75 [00:00<?, ?it/s]
#   0%|          | 0/75 [00:00<?, ?it/s]
#   0%|          | 0/75 [00:00<?, ?it/s]
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(2 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(2 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(2 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(2 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(2 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# Hit rate limit, retrying...(3 left)
# 3000

# %%
import pandas as pd

vsc_df = pd.DataFrame(vsc_qa_rows)

eval_qas_with_hops = pd.read_csv('../data/eval_qas_with_hops.csv', index_col=0)
print(f'OLD EVAL QAS LENGTH: {len(eval_qas_with_hops)}')
eval_qas = pd.concat([eval_qas_with_hops, vsc_df], ignore_index=True)
print(f'NEW QAS LENGTH WITH NEW DATA: {len(eval_qas)}')
eval_qas.to_csv('../data/eval_qas_with_vsc.csv')
# Out:
# OLD EVAL QAS LENGTH: 3336
# NEW QAS LENGTH WITH NEW DATA: 6336

# %%
eval_qas = pd.read_csv('../data/eval_qas_with_vsc.csv', index_col=0)
eval_qas.qa_type.value_counts()
# Out:
# qa_type
# vsc_neighborhood    3000
# 3_hop                885
# 2_hop                885
# 4_hop                885
# single_fact          681
# Name: count, dtype: int64

# %%
import ast
import os
from neo4j import GraphDatabase
from dotenv import load_dotenv

load_dotenv()

graph = GraphDatabase.driver(
    os.environ['NEO4J_URI'],
    auth=(os.environ['NEO4J_USER'], os.environ['NEO4J_PWD'])
)
database = os.environ['NEO4J_DATABASE']


def get_fact_node_id(bird_name: str, title: str) -> str:
	with graph.session(database=database) as session:
		node_result = session.run('''
			MATCH (f:Fact {
				bird_name: $bird_name,
				title: $title	
			})
			RETURN elementId(f) AS id
		''', bird_name=bird_name, title=title).single()
		return node_result['id']


for ind, row in eval_qas.iterrows():
	if row.qa_type == 'single_fact':
		ground_truth = ast.literal_eval(row.ground_truth)
		node_id = get_fact_node_id(ground_truth['bird_name'], ground_truth['title'])
		eval_qas.at[ind, 'node_ids'] = [node_id]

eval_qas.head(5)
# Out:
#                                             question  \
# 0  What distinguishes the Boat-billed Heron from ...
# 1  How can the Plain Prinia be distinguished from...
# 2  What is a distinguishing feature of Monteiro's...
# 3  What are the key identification features of th...
# 4  What are some distinguishing features of the E...
#
#                                               answer      qa_type  \
# 0  The Boat-billed Heron is overall much whiter i...  single_fact
# 1  By its smaller size, less bulky appearance, na...  single_fact
# 2  It has dark grey eyes (not yellow) and a more ...  single_fact
# 3  Large-headed, dark-olive flatbill with white e...  single_fact
# 4  The European Honey-buzzard differs from true b...  single_fact
#
#                                         ground_truth  \
# 0  {'bird_name': 'Boat-billed Heron', 'title': 'I...
# 1  {'bird_name': 'Plain Prinia', 'title': 'Identi...
# 2  {'bird_name': "Monteiro's Bushshrike", 'title'...
# 3  {'bird_name': 'Western Olivaceous Flatbill', '...
# 4  {'bird_name': 'European Honey-buzzard', 'title...
#
#                                           node_ids
# 0  [4:a554891f-4e4e-45d4-beca-f7796c51940f:197847]
# 1  [4:a554891f-4e4e-45d4-beca-f7796c51940f:457779]
# 2  [4:a554891f-4e4e-45d4-beca-f7796c51940f:416657]
# 3  [4:a554891f-4e4e-45d4-beca-f7796c51940f:363358]
# 4  [4:a554891f-4e4e-45d4-beca-f7796c51940f:209969]

# %%
for ind, row in eval_qas.iterrows():
    if row.qa_type in ['2_hop', '3_hop', '4_hop']:
        ground_truth = ast.literal_eval(row.ground_truth)
        node_ids = [
			get_fact_node_id(f['bird_name'], f['title'])
			for f in ground_truth
		]
        eval_qas.at[ind, 'node_ids'] = node_ids

eval_qas[eval_qas.qa_type.isin(['2_hop', '3_hop', '4_hop'])].head(5)
# Out:
#                                               question                 answer  \
# 681  Which species was observed harassing Common Ga...             Giant Coot
# 682  What type of gestures does the Sula Lorikeet t...  Unritualized gestures
# 683  Which bird was found to have a smaller reperto...          Sula Lorikeet
# 684  Which bird species has been observed attacking...             Giant Coot
# 685  Which bird species defends a 30 meter area aro...         Bicolored Hawk
#
#     qa_type                                       ground_truth  \
# 681   2_hop  [{'bird_name': 'Giant Coot', 'title': 'Agonist...
# 682   2_hop  [{'bird_name': 'Giant Coot', 'title': 'Agonist...
# 683   2_hop  [{'bird_name': 'Giant Coot', 'title': 'Agonist...
# 684   2_hop  [{'bird_name': 'Giant Coot', 'title': 'Agonist...
# 685   2_hop  [{'bird_name': 'Giant Coot', 'title': 'Agonist...
#
#                                               node_ids
# 681  [4:a554891f-4e4e-45d4-beca-f7796c51940f:115510...
# 682  [4:a554891f-4e4e-45d4-beca-f7796c51940f:115510...
# 683  [4:a554891f-4e4e-45d4-beca-f7796c51940f:115510...
# 684  [4:a554891f-4e4e-45d4-beca-f7796c51940f:115510...
# 685  [4:a554891f-4e4e-45d4-beca-f7796c51940f:115510...

# %%
import ast

ast.literal_eval(eval_qas[eval_qas.qa_type == 'vsc_neighborhood'].ground_truth.iloc[0])
# Out:
# [{'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Genus", "name": "Clanga"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_image',
#     'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/630362912/480'},
#    {'type': 'input_text',
#     'text': '{"node_label": "Image", "bird_name": "Red-thighed Sparrowhawk"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Family", "name": "Accipitridae"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_image',
#     'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/121313251/640'},
#    {'type': 'input_text',
#     'text': '{"node_label": "Image", "bird_name": "Black-and-white Hawk-Eagle", "title": "Juvenile in flight, dorsal view. The upperwing is brownish, and the wing coverts, including secondary and primary coverts, have pale tips, typical of Juvenile Plumage. The subterminal band is relatively narrow and indistinct. Note also the uniformity to the remiges, without suspension limits or Staffelmauser patterns, and with narrow and pointed outer primaries. "}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Bird", "name": "Greater Spotted Eagle", "order": "Accipitriformes", "family": "Accipitridae", "genus": "Clanga", "species": "Clanga"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Fact", "bird_name": "Bicolored Hawk", "fact_title": "Molts", "content": "GeneralMolt and plumage terminology follows Humphrey and Parkes (9), as modified by Howell et al. (10). Under this nomenclature, terminology is based on evolution of molts along ancestral lineages of birds from ecdysis (molts) of reptiles, rather than on molts relative to breeding season, location, or time of the year, the latter generally referred to as \\u201clife-cycle\\u201d molt terminology (11; see also 12). As in other species formerly considered to be in Accipiter, Bicolored Hawk exhibits a Modified Basic Strategy (c.f. 10, 13), including incomplete-to-complete prebasic molts and a limited preformative molt in some to most individuals (8), but no prealternate molts (6).Prejuvenile (First Prebasic) MoltComplete, in the nest. No information on this molt in Bicolored Hawks. In other species formerly considered to be in Accipiter, sheaths begin to break about 11 d; rectrices, scapulars, and remiges protruding from down by day 21; between days 18\\u201321 contour feathers emerge along the ventral tract around the crop; juvenile feathering nearly complete by 28 d, although rectrices and remiges do not reach full length until 45\\u201354 d.Preformative MoltLimited. Includes some scattered to most body feathers over head, upperparts, and underparts but no flight feathers. Appears to occur in most or all Bicolored Hawks.Second Prebasic MoltIncomplete to complete; appears to be complete in the majority of Bicolored Hawks, especially those in northern portions of range. One to a few juvenile rump feathers and/or upperwing coverts can occasionally be retained; 1\\u20132 rectrices among r2 and r5 can rarely be retained; and 1\\u20136 juvenile secondaries (among s3\\u2013s4 and s7\\u2013s10) occasionally retained (see7, 6); in Bicolored Hawk retained feathers may be limited primarily to secondaries among s3-s4 and s7-s8, more frequently in southern portions of range.Definitive Prebasic MoltIncomplete-to-complete. Primaries replaced distally (p1 to p10), secondaries replaced proximally from s1 and s5 and distally from the tertials (often bilaterally from t2), and rectrices may be replaced in sequence r1\\u2013r3\\u2013r4\\u2013r6\\u2013r5\\u2013r2 on each side of tail, with some variation likely. Molt initiates with primaries, then secondaries, then secondary coverts and rectrices; rectrix, secondary, and most body-feather molt typically begins about 1 mo after onset of primary molt. In other species formerly considered to be in Accipiter, new body feathers appear first on head and foreparts, then elsewhere. One to a few basic rump feathers, upperwing coverts, outer primaries (among p8-p10), and rectrices (among r2 and r5) can rarely be retained; and 1\\u20136 basic secondaries (among s3\\u2013s4 and s7\\u2013s10) may be more frequently retained (7, 6). Following incomplete molts, Staffelmauser or stepwise molt can occur in some individuals, with retained basic feathers occurring in sets among the primaries and at various positions among the secondaries (see 14, 7, 15, 6)."}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Genus", "name": "Tachyspiza"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Genus", "name": "Gyps"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Genus", "name": "Spizaetus"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Genus", "name": "Nisaetus"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Bird", "name": "Meyer\'s Goshawk", "order": "Accipitriformes", "family": "Accipitridae", "genus": "Astur", "species": "Meyerianus"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_image',
#     'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/617966827/640'},
#    {'type': 'input_text',
#     'text': '{"node_label": "Image", "bird_name": "Black-and-white Hawk-Eagle", "title": "Definitive Basic Plumage. Definitive Basic Plumage includes black upperparts (without pale feather fringes) and white forecrown and underparts. Note the broad, truncate, and dusky secondaries and rectrices, basic feathers signifying Definitive Basic Plumage. Sexing is best performed from the barring on the underwing, indeterminable here. Note also the vivid orange cere and bright yellow iris indicating an adult. "}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Order", "name": "Accipitriformes"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_image',
#     'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/243652351/640'},
#    {'type': 'input_text',
#     'text': '{"node_label": "Image", "bird_name": "Bicolored Hawk"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Bird", "name": "Sulawesi Hawk-Eagle", "order": "Accipitriformes", "family": "Accipitridae", "genus": "Nisaetus", "species": "Lanceolatus"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Bird", "name": "Swamp Harrier", "order": "Accipitriformes", "family": "Accipitridae", "genus": "Circus", "species": "Approximans"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Bird", "name": "Black Harrier", "order": "Accipitriformes", "family": "Accipitridae", "genus": "Circus", "species": "Maurus"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_image',
#     'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/175747561/480'},
#    {'type': 'input_text',
#     'text': '{"node_label": "Image", "bird_name": "Bicolored Hawk"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Fact", "bird_name": "Bicolored Hawk", "fact_title": "Sexual Behavior", "content": "No known aerial displays (3)."}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_image',
#     'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/622707639/480'},
#    {'type': 'input_text',
#     'text': '{"node_label": "Image", "bird_name": "Black Harrier"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Bird", "name": "Red-thighed Sparrowhawk", "order": "Accipitriformes", "family": "Accipitridae", "genus": "Tachyspiza", "species": "Erythropus"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Fact", "bird_name": "Red-thighed Sparrowhawk", "fact_title": "Identification", "content": "22\\u201328 cm (1); male 78\\u201394 g, female 132\\u2013170 g; wingspan 45\\u201357 cm (2). Very small size, although Little Sparrowhawk (Tachyspiza minulla) is marginally smaller (1); plump-looking, with relatively tiny bill and long thin legs and toes (2). Dark slate gray to black (2) upperparts with white rump (1), underparts with variable rufous wash or barring, except sharply defined white throat (2), and broken white bars across spread tail distinctive, separating it from Little Sparrowhawk of drier forests. Female much larger than male by mean 14% in size and perhaps 65\\u201375% in mass (2). Might be confused with smaller male of (otherwise larger) African Goshawk (Aerospiza tachiro), which has grayish upperparts and different iris color (3). Bare parts: irides orange to reddish, cere yellow to orange, and legs yellow to orange (1). Juvenile has dark rump (1), is only lightly spotted below with some barring on flanks, and has bare-parts coloration all yellow (1); juvenile Little Sparrowhawk has very heavily dark-spotted underparts (1). Subspecies zenkeri very similar, but c. 5% larger (4), darker above, and usually less saturated with rufous below (female typically has this color overlain with silvery gray, in this respect being similar to Aerospiza tachiro toussenelii) (3), has 1\\u20132 white spots on central rectrices (2) and sometimes more clearly barred below; juvenile zenkeri is weakly streaked or spotted, whereas nominate erythropus at this age has the underparts heavily barred rufous (4). Molts directly to adult plumage either towards end of first year or early in second (2)."}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Bird", "name": "Black-and-white Hawk-Eagle", "order": "Accipitriformes", "family": "Accipitridae", "genus": "Spizaetus", "species": "Melanoleucus"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_image',
#     'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/457631601/640'},
#    {'type': 'input_text',
#     'text': '{"node_label": "Image", "bird_name": "Black-and-white Hawk-Eagle", "title": "Stretching. "}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Bird", "name": "Bicolored Hawk", "order": "Accipitriformes", "family": "Accipitridae", "genus": "Astur", "species": "Bicolor"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Genus", "name": "Astur"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Bird", "name": "Cape Griffon", "order": "Accipitriformes", "family": "Accipitridae", "genus": "Gyps", "species": "Coprotheres"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_image',
#     'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/476960651/640'},
#    {'type': 'input_text',
#     'text': '{"node_label": "Image", "bird_name": "Swamp Harrier", "title": "Possible Confusion species: Square-tailed Kite (Lophoictinia isura). Square-tailed Kite has short legs. "}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_text',
#     'text': '{"node_label": "Genus", "name": "Circus"}'}]},
#  {'role': 'user',
#   'content': [{'type': 'input_image',
#     'image_url': 'https://cdn.download.ams.birds.cornell.edu/api/v1/asset/361761201/640'},
#    {'type': 'input_text',
#     'text': '{"node_label": "Image", "bird_name": "Bicolored Hawk", "title": "Second Basic Bicolored Hawk (subspecies pileatus). A small proportion of second basic Bicolored Hawks can be recognized by retained juvenile secondaries following incomplete Second Prebasic Molts. Here juvenile secondaries are present in typical locations, at s3-s4 and s7. Bicolored Hawks undergoing incomplete molts may be more common at the southern portions of the range and appear to be more common in formerly conspecific Chilean Hawk. In Second Basic Plumage the iris can be yellow or tinged orange. "}'}]}]

# %%
eval_qas[(eval_qas.qa_type == 'vsc_neighborhood') & (pd.isna(eval_qas.node_ids))]
# Out:
#                                                question  \
# 3336  Which genus includes a bird that is very small...
# 3337  Which bird shows no known aerial sexual displa...
# 3338  Which genus includes two harrier species found...
# 3339  Which bird is described as having black upperp...
# 3340  Which bird exhibits a modified basic strategy ...
# ...                                                 ...
# 6194  What breeding habitats are preferred by the Li...
# 6195  How do the adult breeding and juvenile appeara...
# 6196  Which bird species, known for a series of deep...
# 6197  What bird in the genus Taccocua is generally s...
# 6198  Which bird of the order Cuculiformes, depicted...
#
#                                                  answer           qa_type  \
# 3336  The genus Tachyspiza includes the Red-thighed ...  vsc_neighborhood
# 3337  The Bicolored Hawk shows no known aerial sexua...  vsc_neighborhood
# 3338  The genus Circus includes the Swamp Harrier an...  vsc_neighborhood
# 3339  The Black-and-white Hawk-Eagle has black upper...  vsc_neighborhood
# 3340  The Bicolored Hawk exhibits a modified basic s...  vsc_neighborhood
# ...                                                 ...               ...
# 6194  The Little Ringed Plover prefers breeding in s...  vsc_neighborhood
# 6195  Adult breeding Black-tailed Gulls have white h...  vsc_neighborhood
# 6196                                    Greater Coucal.  vsc_neighborhood
# 6197                                   Sirkeer Malkoha.  vsc_neighborhood
# 6198                                     Common Cuckoo.  vsc_neighborhood
#
#                                            ground_truth node_ids
# 3336  [{'role': 'user', 'content': [{'type': 'input_...      NaN
# 3337  [{'role': 'user', 'content': [{'type': 'input_...      NaN
# 3338  [{'role': 'user', 'content': [{'type': 'input_...      NaN
# 3339  [{'role': 'user', 'content': [{'type': 'input_...      NaN
# 3340  [{'role': 'user', 'content': [{'type': 'input_...      NaN
# ...                                                 ...      ...
# 6194  [{'role': 'user', 'content': [{'type': 'input_...      NaN
# 6195  [{'role': 'user', 'content': [{'type': 'input_...      NaN
# 6196  [{'role': 'user', 'content': [{'type': 'input_...      NaN
# 6197  [{'role': 'user', 'content': [{'type': 'input_...      NaN
# 6198  [{'role': 'user', 'content': [{'type': 'input_...      NaN
#
# [2863 rows x 5 columns]

# %%
import pandas as pd
eval_qas = pd.read_csv('../data/eval_qas_with_node_ids.csv', index_col=0)
len(eval_qas)

for ind, row in eval_qas[eval_qas.qa_type == '4_hop'].iterrows():
	print(f'ROW {ind} ------------------')
	print(f'Q: ', row.question)
	print(f'A: ', row.answer)
	print(f'G: ', row.ground_truth)

# in the provided facts... etc
# ROW 699 :: Which bird has a bluish gray bill and which has a bright yellow bill in adulthood?
# ROW 711 :: Which bird is described as having behavior similar to another species, and which one is described with details about its perching and foraging habits?
# 3 hop not taking all references into consideration

# personas
# Out:
# ROW 2451 ------------------
# Q:  Which bird is reported to defend a 30 meter area around its nest from both raptors and large passerines, as well as primates?
# A:  Bicolored Hawk
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Chestnut-bellied Chat-Tyrant', 'title': 'Agonistic Behavior', 'text': 'No information.'}]
# ROW 2452 ------------------
# Q:  Which bird in Northern Chile has immatures that harass and attack Common Gallinule juveniles with their feet, with adults sometimes intimidating Common Gallinule as well?
# A:  Giant Coot
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Chestnut-bellied Chat-Tyrant', 'title': 'Agonistic Behavior', 'text': 'No information.'}]
# ROW 2453 ------------------
# Q:  Which lorikeet species was found to have a smaller repertoire of distinct agonistic gestures and to use unritualized gestures more than most other species in a mirror-image stimulation study?
# A:  Sula Lorikeet
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Chestnut-bellied Chat-Tyrant', 'title': 'Agonistic Behavior', 'text': 'No information.'}]
# ROW 2454 ------------------
# Q:  Which bird was observed attacking Common Gallinule juveniles with its feet in Northern Chile?
# A:  Giant Coot
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Kentish Plover', 'title': 'Agonistic Behavior', 'text': 'Territorial; feeds in neutral area outside territory.'}]
# ROW 2455 ------------------
# Q:  Which species was found to have a smaller repertoire of distinct agonistic gestures and relied more on unritualized gestures compared to most other lorikeets?
# A:  Sula Lorikeet
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Kentish Plover', 'title': 'Agonistic Behavior', 'text': 'Territorial; feeds in neutral area outside territory.'}]
# ROW 2456 ------------------
# Q:  Which bird defends an area of 30 meters around its nest from other birds and primates?
# A:  Bicolored Hawk
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Kentish Plover', 'title': 'Agonistic Behavior', 'text': 'Territorial; feeds in neutral area outside territory.'}]
# ROW 2457 ------------------
# Q:  Which bird is reported to harass or intimidate Common Gallinule juveniles and adults in Northern Chile?
# A:  Giant Coot
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Collared Inca', 'title': 'Agonistic Behavior', 'text': 'Like many hummingbirds, is known interact aggressively with other individuals at hummingbird feeders.Aggressive interactions (subspecies torquata)Aggressive interactions (subspecies torquata)Aggressive interactions (subspecies torquata)seekmute0:00 / 0:39Agonistic behavior between two males (subspecies torquata)© Jay McGowanNapo, Ecuador 12 Feb 2016Macaulay Library ML 488175eBirdS27755766'}]
# ROW 2458 ------------------
# Q:  Which species was found to have a smaller repertoire of distinct agonistic gestures and to use unritualized gestures more than most other lorikeets in a mirror-image stimulation study?
# A:  Sula Lorikeet
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Collared Inca', 'title': 'Agonistic Behavior', 'text': 'Like many hummingbirds, is known interact aggressively with other individuals at hummingbird feeders.Aggressive interactions (subspecies torquata)Aggressive interactions (subspecies torquata)Aggressive interactions (subspecies torquata)seekmute0:00 / 0:39Agonistic behavior between two males (subspecies torquata)© Jay McGowanNapo, Ecuador 12 Feb 2016Macaulay Library ML 488175eBirdS27755766'}]
# ROW 2459 ------------------
# Q:  Which bird defends an area of 30 meters around its nest from other birds and primates?
# A:  Bicolored Hawk
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Collared Inca', 'title': 'Agonistic Behavior', 'text': 'Like many hummingbirds, is known interact aggressively with other individuals at hummingbird feeders.Aggressive interactions (subspecies torquata)Aggressive interactions (subspecies torquata)Aggressive interactions (subspecies torquata)seekmute0:00 / 0:39Agonistic behavior between two males (subspecies torquata)© Jay McGowanNapo, Ecuador 12 Feb 2016Macaulay Library ML 488175eBirdS27755766'}]
# ROW 2460 ------------------
# Q:  Which bird was observed harassing Common Gallinule juveniles with its feet in Fuerte Baquedano, Northern Chile?
# A:  Giant Coot
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Indian Cuckooshrike', 'title': 'Agonistic Behavior', 'text': 'Territorial BehaviorThe loud calls by both sexes are presumed to be pairs defending territories (3).'}]
# ROW 2461 ------------------
# Q:  Which bird species was found to have a smaller repertoire of distinct agonistic gestures and used unritualized gestures more than most other species in a mirror-image stimulation study?
# A:  Sula Lorikeet
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Indian Cuckooshrike', 'title': 'Agonistic Behavior', 'text': 'Territorial BehaviorThe loud calls by both sexes are presumed to be pairs defending territories (3).'}]
# ROW 2462 ------------------
# Q:  Which bird defends an area of 30 m around its nest from other birds, including raptors, large passerines, and primates?
# A:  Bicolored Hawk
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Indian Cuckooshrike', 'title': 'Agonistic Behavior', 'text': 'Territorial BehaviorThe loud calls by both sexes are presumed to be pairs defending territories (3).'}]
# ROW 2463 ------------------
# Q:  Which bird in Fuerte Baquedano, Northern Chile, was observed harassing Common Gallinule juveniles with its feet?
# A:  Giant Coot
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Gilolo Fantail', 'title': 'Agonistic Behavior', 'text': 'Territorial BehaviorPresumably territorial, as Australian Rufous Fantail (Rhipidura rufifrons).'}]
# ROW 2464 ------------------
# Q:  Which species was found to have a smaller repertoire of distinct agonistic gestures and tended to use unritualized gestures more than most other lorikeets in a mirror-image stimulation study?
# A:  Sula Lorikeet
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Gilolo Fantail', 'title': 'Agonistic Behavior', 'text': 'Territorial BehaviorPresumably territorial, as Australian Rufous Fantail (Rhipidura rufifrons).'}]
# ROW 2465 ------------------
# Q:  Which bird defends an area of 30 meters around its nest from other birds and primates?
# A:  Bicolored Hawk
# G:  [{'bird_name': 'Giant Coot', 'title': 'Agonistic Behavior', 'text': 'In Fuerte Baquedano, Northern Chile, immatures of this species harassed Common Gallinule juveniles, attacking them with their feet. Sometimes the adults also intimidated Common Gallinule (2).'}, {'bird_name': 'Sula Lorikeet', 'title': 'Agonistic Behavior', 'text': 'In a study of agonistic behavior in captive lorikeets using mirror-image stimulation, it was found that the "Yellow-and-green Lorikeet" (then considered conspecific with the Yellow-cheeked Lorikeet, and race not specified) had a smaller repertoire of distinct agonistic gestures than most other species, and it tended to use unritualized gestures more than most other species (22).'}, {'bird_name': 'Bicolored Hawk', 'title': 'Agonistic Behavior', 'text': 'Both sexes defend area of 30 m around nest from other birds, both raptors and large passerines, as well as primates (3).'}, {'bird_name': 'Gilolo Fantail', 'title': 'Agonistic Behavior', 'text': 'Territorial BehaviorPresumably territorial, as Australian Rufous Fantail (Rhipidura rufifrons).'}]
# ROW 2466 ------------------
# Q:  Which bird has a bill that is bright yellow tinged reddish orange or red at the base in adults, and which bird has a bill that is bluish gray?
# A:  The Vinous-breasted Myna has a bill that is bright yellow tinged reddish orange or red at the base in adults, while the Rote Boobook has a bill that is bluish gray.
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Vinous-breasted Myna', 'title': 'Bare Parts', 'text': 'BillBright yellow tinged reddish orange or red at the base (sometimes, on the basis of  graphs, only a relatively small distal portion of the bill is yellow). In juveniles, the bill is dull brownish yellow with a paler tip (1).IrisMainly whitish (but perhaps variable, details unclear), with bare skin from lores extending around and below eye and to above ear-coverts black (1). Juveniles have the eyes brown to pale brownish yellow (1).Legs and FeetOrange-yellow to yellow in adults; brownish yellow in juveniles (1).Adult showing head detail.© Yonatan GordonTel-Aviv, Israel 27 Nov 2021Macaulay Library ML 391352041eBirdS98143789'}]
# ROW 2467 ------------------
# Q:  Which bird has legs that are feathered and buff mottled with rufous-brown, and which has legs and feet that are pale pink or pink?
# A:  The Rote Boobook has legs that are feathered and buff mottled with rufous-brown, while the White-tailed Cisticola has legs and feet that are pale pink or pink.
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Vinous-breasted Myna', 'title': 'Bare Parts', 'text': 'BillBright yellow tinged reddish orange or red at the base (sometimes, on the basis of  graphs, only a relatively small distal portion of the bill is yellow). In juveniles, the bill is dull brownish yellow with a paler tip (1).IrisMainly whitish (but perhaps variable, details unclear), with bare skin from lores extending around and below eye and to above ear-coverts black (1). Juveniles have the eyes brown to pale brownish yellow (1).Legs and FeetOrange-yellow to yellow in adults; brownish yellow in juveniles (1).Adult showing head detail.© Yonatan GordonTel-Aviv, Israel 27 Nov 2021Macaulay Library ML 391352041eBirdS98143789'}]
# ROW 2468 ------------------
# Q:  Which bird has a bright and pale yellow to grayish-yellow iris in adults and yellow tarsi and toes at all ages?
# A:  The White-tailed Eagle.
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Vinous-breasted Myna', 'title': 'Bare Parts', 'text': 'BillBright yellow tinged reddish orange or red at the base (sometimes, on the basis of  graphs, only a relatively small distal portion of the bill is yellow). In juveniles, the bill is dull brownish yellow with a paler tip (1).IrisMainly whitish (but perhaps variable, details unclear), with bare skin from lores extending around and below eye and to above ear-coverts black (1). Juveniles have the eyes brown to pale brownish yellow (1).Legs and FeetOrange-yellow to yellow in adults; brownish yellow in juveniles (1).Adult showing head detail.© Yonatan GordonTel-Aviv, Israel 27 Nov 2021Macaulay Library ML 391352041eBirdS98143789'}]
# ROW 2469 ------------------
# Q:  Which bird has a bill that is bluish gray, an iris that is vivid yellow in adults, and legs that are buff mottled with rufous-brown?
# A:  Rote Boobook
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Black-breasted Kite', 'title': 'Bare Parts', 'text': 'The following is based on descriptions in Marchant and Higgins (7) and Thiollay (8), along with examination of Macaulay Library images. See also images under Plumages.Bill, Cere, and GapeThe bill is large and strongly hooked as typical of Accipitridae. In adults, it is pink at the base with a black tip, variable in length. The cere is similar in color but paler or washed pale grayish, and contains sparse bristles. In nestlings and juveniles, these colors are similar but the bill base and cere is pale bluish-gray. The gape at all ages is pinkish white and it is swollen in nestlings and young juveniles.Iris and Facial SkinIn adults the iris is brown, with a slight chestnut tinge in older birds. In nestlings and juveniles the iris is duller and can be tinged grayish. The orbital skin is the same color as the cere, pale pinkish or washed pale grayish.Tarsus and ToesThe legs and feet are large and strong, with sharp talons. In adults they are pale pinkish to pinkish gray and in nestlings they may be grayer. The talons at all ages are horn colored.Adults.Adult.Nesttlings.'}]
# ROW 2470 ------------------
# Q:  Of the birds described, which one has pale pink or pink legs and feet and a slender, slightly curved bill that is black to dark horn-colored with a pale ivory-yellow base to the mandible?
# A:  White-tailed Cisticola
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Black-breasted Kite', 'title': 'Bare Parts', 'text': 'The following is based on descriptions in Marchant and Higgins (7) and Thiollay (8), along with examination of Macaulay Library images. See also images under Plumages.Bill, Cere, and GapeThe bill is large and strongly hooked as typical of Accipitridae. In adults, it is pink at the base with a black tip, variable in length. The cere is similar in color but paler or washed pale grayish, and contains sparse bristles. In nestlings and juveniles, these colors are similar but the bill base and cere is pale bluish-gray. The gape at all ages is pinkish white and it is swollen in nestlings and young juveniles.Iris and Facial SkinIn adults the iris is brown, with a slight chestnut tinge in older birds. In nestlings and juveniles the iris is duller and can be tinged grayish. The orbital skin is the same color as the cere, pale pinkish or washed pale grayish.Tarsus and ToesThe legs and feet are large and strong, with sharp talons. In adults they are pale pinkish to pinkish gray and in nestlings they may be grayer. The talons at all ages are horn colored.Adults.Adult.Nesttlings.'}]
# ROW 2471 ------------------
# Q:  Which bird is described as having a large, strongly hooked bill that is pink at the base with a black tip in adults, an iris that is brown with a chestnut tinge in older birds, and pale pinkish to pinkish gray legs and feet?
# A:  Black-breasted Kite
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Black-breasted Kite', 'title': 'Bare Parts', 'text': 'The following is based on descriptions in Marchant and Higgins (7) and Thiollay (8), along with examination of Macaulay Library images. See also images under Plumages.Bill, Cere, and GapeThe bill is large and strongly hooked as typical of Accipitridae. In adults, it is pink at the base with a black tip, variable in length. The cere is similar in color but paler or washed pale grayish, and contains sparse bristles. In nestlings and juveniles, these colors are similar but the bill base and cere is pale bluish-gray. The gape at all ages is pinkish white and it is swollen in nestlings and young juveniles.Iris and Facial SkinIn adults the iris is brown, with a slight chestnut tinge in older birds. In nestlings and juveniles the iris is duller and can be tinged grayish. The orbital skin is the same color as the cere, pale pinkish or washed pale grayish.Tarsus and ToesThe legs and feet are large and strong, with sharp talons. In adults they are pale pinkish to pinkish gray and in nestlings they may be grayer. The talons at all ages are horn colored.Adults.Adult.Nesttlings.'}]
# ROW 2472 ------------------
# Q:  Which bird has a bill that is bluish gray, an iris that is vivid yellow in adults, and legs that are feathered and buff mottled with rufous-brown?
# A:  Rote Boobook
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Western Striolated-Puffbird', 'title': 'Bare Parts', 'text': 'Irispale ochreBillyellow-olive, with very variable blackish-brown tip and base of mandibleTarsi and Toeslegs brown, feet dusky yellow-olive'}]
# ROW 2473 ------------------
# Q:  Which bird has tarsi and toes that are yellow at all ages, an adult bill and cere that are bright yellow, and an iris that is bright and pale yellow to grayish-yellow in adults?
# A:  White-tailed Eagle
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Western Striolated-Puffbird', 'title': 'Bare Parts', 'text': 'Irispale ochreBillyellow-olive, with very variable blackish-brown tip and base of mandibleTarsi and Toeslegs brown, feet dusky yellow-olive'}]
# ROW 2474 ------------------
# Q:  Which bird has a slender, slightly curved bill that can be black to dark horn-colored with a pale ivory-yellow base to the mandible or gray with a pale gray proximal half, a pale brown or tawny iris, and pale pink or pink legs and feet?
# A:  White-tailed Cisticola
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Western Striolated-Puffbird', 'title': 'Bare Parts', 'text': 'Irispale ochreBillyellow-olive, with very variable blackish-brown tip and base of mandibleTarsi and Toeslegs brown, feet dusky yellow-olive'}]
# ROW 2475 ------------------
# Q:  Which bird has adults with a bright yellow bill and cere, and tarsi and toes that are yellow at all ages?
# A:  White-tailed Eagle
# G:  [{'bird_name': 'Rote Boobook', 'title': 'Bare Parts', 'text': 'BillBluish gray (5).IrisVivid yellow (in adults) with gray orbital skin (1).Legs and FeetLegs feathered, and buff mottled with rufous-brown; feet gray (1).'}, {'bird_name': 'White-tailed Cisticola', 'title': 'Bare Parts', 'text': 'BillSlender and slightly curved; black to dark horn-colored, with a pale ivory-yellow base to the mandible, or gray with pale gray proximal half to the mandible (1).IrisPale brown or tawny (1).Legs and FeetPale pink or pink (1).'}, {'bird_name': 'White-tailed Eagle', 'title': 'Bare Parts', 'text': "Based on information in Dement'ev and Gladkov (5), Cramp and Simmons (22), and Forsman (6), along with examination of Macaulay Library images; for reference see those according to age in the Plumage section.Bill, Cere, and GapeIn adults, the bill and cere are bright yellow. In nestlings, the cere can be dusky gray and the bill is mostly black; the gape can be swollen and bright yellow (see image under Juvenile Plumage). During the first year the cere becomes pale yellow before attaining brighter yellow color of adults. The bill remains mostly black, variably transitioning to yellow over the first 2–4 years.IrisIn adults the iris is bright and pale yellow to grayish-yellow. In nestlings and juveniles the iris is dark, gradually becoming yellowish-brown, brownish-yellow, and dull yellow over the first 3–4 years before reaching the coloration of adults.Tarsi and ToesAt all ages the tarsi and toes are yellow, perhaps being duller or pinker in nestlings. The claws are black.Adult White-tailed Eagles (subspecies albicilla). First-year or Second-year White-tailed Eagle (subspecies albicilla). Third-year or Fourth-year White-tailed Eagle (subspecies albicilla)."}, {'bird_name': 'Wedge-tailed Green-Pigeon', 'title': 'Bare Parts', 'text': 'The following is based on descriptions in Baptista et al. (1) and Wells (2), along with examination of Macaulay Library images. See also images under Plumages for age-related variation in bare-parts colors and rates of change.Bill and CereIn adults of both sexes, the bill and cere are medium bright to bright pale blue, the tip sometimes tinged dusky. In juveniles, the bill is pinkish with a dark tip and the cere is dusky pink. In first-year birds, bill colors transition during the Preformative Molt and appear to reach those of adults at about a year of age.Iris and Facial SkinIn adult males, the outer rim of the iris is dark reddish with blackish and blue rings surrounding the dark pupil. In adult females, the outer and inner rings are bright brown to olive-brown. The thin orbital skin is pale blue, similar in color or slightly paler than the bill. In juveniles, the iris is like that of females but duller brown, and the orbital skin is duller and washed pinkish.Tarsi and ToesIn adults, the legs and feet are bright rosy red. In juveniles, the legs and feet are dull dusky pink, becoming brighter pale pink to rose in the first year. The claws are gray.Adult Female (subspecies sphenurus)..Adult Male (subspecies sphenurus).Juvenile (subspecies sphenurus)..'}]
# ROW 2476 ------------------
# Q:  Which bird has a slender, slightly curved bill that is black to dark horn-colored with a pale ivory-yellow base to the mandible, and pale pink or pink legs and feet?
# A:  White-tailed Cisticola
# ...
# ROW 3321 ------------------
# Q:  Which bird is documented to have nestlings that leave the nest after about eight weeks in captivity?
# A:  Hispaniolan Parakeet
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Bounty Islands Shag', 'title': 'Young Birds', 'text': '© Roksana and TerryCanterbury, New Zealand 16 Dec 2023Macaulay Library ML 614853208eBirdS156406775'}]
# ROW 3322 ------------------
# Q:  Which bird's chicks are described as having white down?
# A:  Black-breasted Kite
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Bounty Islands Shag', 'title': 'Young Birds', 'text': '© Roksana and TerryCanterbury, New Zealand 16 Dec 2023Macaulay Library ML 614853208eBirdS156406775'}]
# ROW 3323 ------------------
# Q:  Which bird was observed as a downy chick in Imbabura, Ecuador, in November?
# A:  Ecuadorian Rail
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Bounty Islands Shag', 'title': 'Young Birds', 'text': '© Roksana and TerryCanterbury, New Zealand 16 Dec 2023Macaulay Library ML 614853208eBirdS156406775'}]
# ROW 3324 ------------------
# Q:  Which bird is documented to have nestlings that leave the nest after about eight weeks in captivity?
# A:  Hispaniolan Parakeet
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Ashy Tailorbird', 'title': 'Young Birds', 'text': 'Young birds.'}]
# ROW 3325 ------------------
# Q:  Which two birds are specifically described as having downy chicks?
# A:  Ecuadorian Rail and Black-breasted Kite
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Ashy Tailorbird', 'title': 'Young Birds', 'text': 'Young birds.'}]
# ROW 3326 ------------------
# Q:  Which bird is mentioned only as having 'young birds' without additional detail?
# A:  Ashy Tailorbird
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Ashy Tailorbird', 'title': 'Young Birds', 'text': 'Young birds.'}]
# ROW 3327 ------------------
# Q:  Which bird's young are noted to leave the nest after about eight weeks in captivity?
# A:  Hispaniolan Parakeet
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Spotted Shag', 'title': 'Young Birds', 'text': 'Young birds grow grey down.'}]
# ROW 3328 ------------------
# Q:  What color down do the chicks of the Black-breasted Kite and Spotted Shag have?
# A:  Black-breasted Kite chicks have white down; Spotted Shag young grow grey down.
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Spotted Shag', 'title': 'Young Birds', 'text': 'Young birds grow grey down.'}]
# ROW 3329 ------------------
# Q:  Which bird's downy chick was observed in Imbabura, Ecuador in November?
# A:  Ecuadorian Rail
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Spotted Shag', 'title': 'Young Birds', 'text': 'Young birds grow grey down.'}]
# ROW 3330 ------------------
# Q:  Which bird had three nestlings leave the nest after about eight weeks in captivity?
# A:  Hispaniolan Parakeet
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'North Solomons Dwarf-Kingfisher', 'title': 'Young Birds', 'text': 'Bougainville Dwarf-Kingfisher (pallidus)A single chick nearly ready to fledge was found in a nest burrow in early September (15), and a female fledgling was collected in late September (1).North Solomons Dwarf-Kingfisher (meeki)Information needed.'}]
# ROW 3331 ------------------
# Q:  Which bird had a chick nearly ready to fledge found in a nest burrow in early September?
# A:  North Solomons Dwarf-Kingfisher
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'North Solomons Dwarf-Kingfisher', 'title': 'Young Birds', 'text': 'Bougainville Dwarf-Kingfisher (pallidus)A single chick nearly ready to fledge was found in a nest burrow in early September (15), and a female fledgling was collected in late September (1).North Solomons Dwarf-Kingfisher (meeki)Information needed.'}]
# ROW 3332 ------------------
# Q:  Which bird's chicks have white down?
# A:  Black-breasted Kite
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'North Solomons Dwarf-Kingfisher', 'title': 'Young Birds', 'text': 'Bougainville Dwarf-Kingfisher (pallidus)A single chick nearly ready to fledge was found in a nest burrow in early September (15), and a female fledgling was collected in late September (1).North Solomons Dwarf-Kingfisher (meeki)Information needed.'}]
# ROW 3333 ------------------
# Q:  Which bird's young fledge in 14–15 days, sometimes as early as ten days?
# A:  Tumbesian Tyrannulet
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Tumbesian Tyrannulet', 'title': 'Young Birds', 'text': 'At hatching, young have blackish skin and off-white down, fledge in 14–15 days (once apparently just ten days). In one Ecuadorian study, just two (of ten) monitored nests failed completely (12, 13). No further information.'}]
# ROW 3334 ------------------
# Q:  Which bird had three nestlings that left the nest after about eight weeks in captivity?
# A:  Hispaniolan Parakeet
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Tumbesian Tyrannulet', 'title': 'Young Birds', 'text': 'At hatching, young have blackish skin and off-white down, fledge in 14–15 days (once apparently just ten days). In one Ecuadorian study, just two (of ten) monitored nests failed completely (12, 13). No further information.'}]
# ROW 3335 ------------------
# Q:  Which bird's chicks have white down?
# A:  Black-breasted Kite
# G:  [{'bird_name': 'Hispaniolan Parakeet', 'title': 'Young Birds', 'text': 'In captivity, 3 nestlings left the nest after about eight weeks (13).'}, {'bird_name': 'Ecuadorian Rail', 'title': 'Young Birds', 'text': 'Downy chick; November, Imbabura, Ecuador.© Lars Petersson | My World of Bird  graphyImbabura, Ecuador 19 Nov 2019Macaulay Library ML 202939851eBirdS63792186'}, {'bird_name': 'Black-breasted Kite', 'title': 'Young Birds', 'text': 'Chicks have white down.Adult with downy chick.© David NewellUnincorporated SA, South Australia, Australia 10 Nov 2020Macaulay Library ML 280175671eBirdS76174591'}, {'bird_name': 'Tumbesian Tyrannulet', 'title': 'Young Birds', 'text': 'At hatching, young have blackish skin and off-white down, fledge in 14–15 days (once apparently just ten days). In one Ecuadorian study, just two (of ten) monitored nests failed completely (12, 13). No further information.'}]

# %%
from transformers import pipeline
import numpy as np

# Load a small, specialized SQuAD 2.0 model (approx 500MB)
# This model is designed to return NO answer if the text doesn't support it.
qa_pipeline = pipeline(
    "question-answering",
    model="deepset/roberta-base-squad2",
    tokenizer="deepset/roberta-base-squad2"
)

# %%
import os
from neo4j import GraphDatabase
from dotenv import load_dotenv
from openai import OpenAI
import json

load_dotenv()

graph = GraphDatabase.driver(
    os.environ['NEO4J_URI'],
    auth=(os.environ['NEO4J_USER'], os.environ['NEO4J_PWD'])
)
database = os.environ['NEO4J_DATABASE']

client = OpenAI()

def find_is_source_related(
	source: dict,
	question: str,
	answer: str,
	model='gpt-4.1',
) -> bool:

	neighborhood_prompt = '''
You are a Q&A source evaluator. Your job is to take a question and answer pair, as well as a source in TEXT or IMAGE form, and return whether or not that source is related to or supports the Q&A pair.
You will take 3 inputs in this order:

- Input 1: the question
- Input 2: the answer
- Input 3: the source. The source will either be a json object with a node_label key which describes what type of source it is and its associated attributes, or an image input followed by its caption. The caption for an image input will also be in json object format.

If the source pertains to the question, and supports the answer, return {"value": true}. Return {"value": false} if the source is irrelevant or does not support the answer. Do not explain.
'''

	resp = client.responses.create(
		model=model,
		instructions=neighborhood_prompt,
		input=[
			{ 
    			'role': 'user',
				'content': [{
					'type': 'input_text',
					'text': question
				}]
    		},
			{
				'role': 'user',
				'content': [{
					'type': 'input_text',
					'text': answer
				}]	
			},
			source
		],
		text={
			'format': {
				'type': 'json_schema',
				'name': 'yes_or_no',
				'strict': True,
				'schema': {
					'type': 'object',
					'properties': {
						'value': {
							'type': 'boolean'
						}
					},
					'required': ['value'],
					'additionalProperties': False
				}
			}
		},
	)

	return json.loads(resp.output_text)


def find_node_id(input_json: dict) -> str:
	with graph.session(database=database) as session:
		content = input_json['content']
		if len(content) > 1:
			img_url = content[0]['image_url']
			node_result = session.run('''
				MATCH (i:Image {
					url: $url	
				})
				RETURN elementId(i) AS id
            ''', url=img_url).single()
			return node_result['id']
		else: 
			payload = json.loads(content[0]['text'])
			if payload['node_label'] == 'Fact':
				return get_fact_node_id(payload['bird_name'], payload['fact_title'])
			else:
				node_result = session.run(f'''
					MATCH (x:{payload['node_label']} {{
						name: $name
					}})
					RETURN elementId(x) AS id
				''', name=payload['name']).single()
				return node_result['id']


def get_fact_node_id(bird_name: str, title: str) -> str:
	with graph.session(database=database) as session:
		node_result = session.run('''
			MATCH (f:Fact {
				bird_name: $bird_name,
				title: $title	
			})
			RETURN elementId(f) AS id
		''', bird_name=bird_name, title=title).single()
		return node_result['id']

'''
sample_vsc_row = eval_qas[eval_qas.qa_type == 'vsc_neighborhood'].iloc[0]
sample_ground_truth = ast.literal_eval(sample_vsc_row.ground_truth)
print(f'Q: {sample_vsc_row.question}')
print(f'A: {sample_vsc_row.answer}')

for g in sample_ground_truth:
	print('GROUND_TRUTH: ', g)
	is_related = find_is_source_related(g, sample_vsc_row.question, sample_vsc_row.answer)
	print('IS RELATED: ', is_related)
	node_id = find_node_id(g)
	print('NODE ID: ', node_id)
'''
# Out:
# "\nsample_vsc_row = eval_qas[eval_qas.qa_type == 'vsc_neighborhood'].iloc[0]\nsample_ground_truth = ast.literal_eval(sample_vsc_row.ground_truth)\nprint(f'Q: {sample_vsc_row.question}')\nprint(f'A: {sample_vsc_row.answer}')\n\nfor g in sample_ground_truth:\n\tprint('GROUND_TRUTH: ', g)\n\tis_related = find_is_source_related(g, sample_vsc_row.question, sample_vsc_row.answer)\n\tprint('IS RELATED: ', is_related)\n\tnode_id = find_node_id(g)\n\tprint('NODE ID: ', node_id)\n"

# %%
import ast
import openai
import threading
import time
from datetime import datetime

num_workers = 12

vsc_qa_indexes = list(eval_qas[
	(eval_qas.qa_type == 'vsc_neighborhood') &
	(pd.isna(eval_qas.node_ids))
].index)
total_length = len(vsc_qa_indexes)

parsed_vsc_qas = {}

lock = threading.Lock()


def qa_val_vsc_worker(thread_id):

	while (len(vsc_qa_indexes) > 0):

		with lock:
			print(f'{datetime.now()} :: WORKER {thread_id} :: PARSING {(total_length-len(vsc_qa_indexes))+1}/{total_length}')
			ind = vsc_qa_indexes.pop()

		row = eval_qas.iloc[ind]
		ground_truth = ast.literal_eval(row.ground_truth)

		nodes = []
		correct_gt = []

		for g in ground_truth:

			retries = 5
			done = False

			while retries > 0 and not done:
				try:
					is_related = find_is_source_related(g, row.question, row.answer)
					if is_related['value']:
						node_id = find_node_id(g)
						with lock:
							correct_gt.append(g)
							nodes.append(node_id)
					done = True
				except openai.RateLimitError:
					print(f'{datetime.now()} :: WORKER {thread_id} :: Rate Limit Hit ({retries} retries left)')
					time.sleep(15)
					retries -= 1
				except openai.InternalServerError:
					print(f'{datetime.now()} :: WORKER {thread_id} :: Internal Server Error ({retries} retries left)')
					time.sleep(15)
					retries -= 1

			if not done:
				raise Exception(f'{datetime.now()} :: WORKER {thread_id} :: MAX RETRIES HIT')
		
		with lock:
			eval_qas.at[ind, 'ground_truth'] = correct_gt
			eval_qas.at[ind, 'node_ids'] = nodes
	
	print(f'WORKER {thread_id} FINISHED')


threads = [
	threading.Thread(target=qa_val_vsc_worker, args=(tid, ))
	for tid in range(num_workers)
]

for t in threads:
    t.start()
for t in threads:
    t.join()
# Out:
# 2025-11-22 16:19:13.267942 :: WORKER 0 :: PARSING 1/2984
# 2025-11-22 16:19:13.268943 :: WORKER 1 :: PARSING 2/2984
# 2025-11-22 16:19:13.269689 :: WORKER 2 :: PARSING 3/2984
# 2025-11-22 16:19:13.270383 :: WORKER 3 :: PARSING 4/2984
# 2025-11-22 16:19:13.270952 :: WORKER 4 :: PARSING 5/2984
# 2025-11-22 16:19:13.271524 :: WORKER 5 :: PARSING 6/2984
# 2025-11-22 16:19:13.272244 :: WORKER 6 :: PARSING 7/2984
# 2025-11-22 16:19:13.272881 :: WORKER 7 :: PARSING 8/2984
# 2025-11-22 16:19:13.273413 :: WORKER 8 :: PARSING 9/2984
# 2025-11-22 16:19:13.274044 :: WORKER 9 :: PARSING 10/2984
# 2025-11-22 16:19:13.274599 :: WORKER 10 :: PARSING 11/2984
# 2025-11-22 16:19:13.275450 :: WORKER 11 :: PARSING 12/2984
# 2025-11-22 16:19:41.292913 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:19:56.198001 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:20:02.914196 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:20:06.023386 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:20:36.463543 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:20:36.813772 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:20:44.945513 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:21:06.858519 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:21:19.916553 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:21:28.654269 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:21:32.907668 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:21:33.692860 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:21:43.612370 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:21:50.668331 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:21:50.727285 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:21:52.290779 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:22:02.594862 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:22:02.928228 :: WORKER 3 :: PARSING 13/2984
# 2025-11-22 16:22:07.818957 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:22:09.979287 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:22:26.378971 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:22:26.746763 :: WORKER 9 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:22:38.825165 :: WORKER 0 :: PARSING 14/2984
# 2025-11-22 16:22:39.717927 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:22:44.424517 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:22:46.512104 :: WORKER 1 :: PARSING 15/2984
# 2025-11-22 16:22:52.145032 :: WORKER 2 :: PARSING 16/2984
# 2025-11-22 16:22:58.423522 :: WORKER 9 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:22:59.554122 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:23:04.736480 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:23:13.453044 :: WORKER 5 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:23:33.356717 :: WORKER 9 :: Rate Limit Hit (2 retries left)
# 2025-11-22 16:23:36.486202 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:23:36.818956 :: WORKER 7 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:23:37.871461 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:23:43.430181 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:23:50.407019 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:23:55.299197 :: WORKER 11 :: PARSING 17/2984
# 2025-11-22 16:23:55.643223 :: WORKER 8 :: PARSING 18/2984
# 2025-11-22 16:24:02.570696 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:24:09.402317 :: WORKER 4 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:24:12.177195 :: WORKER 6 :: PARSING 19/2984
# 2025-11-22 16:24:13.815112 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:24:19.883353 :: WORKER 10 :: PARSING 20/2984
# 2025-11-22 16:24:35.862871 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:24:41.190837 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:24:42.059254 :: WORKER 4 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:24:42.219040 :: WORKER 7 :: PARSING 21/2984
# 2025-11-22 16:24:48.969366 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:24:53.108289 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:24:53.701378 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:25:02.213277 :: WORKER 3 :: PARSING 22/2984
# 2025-11-22 16:25:02.590270 :: WORKER 5 :: PARSING 23/2984
# 2025-11-22 16:25:21.812489 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:25:28.793405 :: WORKER 0 :: PARSING 24/2984
# 2025-11-22 16:25:36.647114 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:25:48.770333 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:25:54.527850 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:25:54.904012 :: WORKER 3 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:26:00.489185 :: WORKER 9 :: PARSING 25/2984
# 2025-11-22 16:26:13.320374 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:26:16.123469 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:26:16.674829 :: WORKER 4 :: PARSING 26/2984
# 2025-11-22 16:26:17.242379 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:26:22.270517 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:26:23.621947 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:26:40.735942 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:26:46.554600 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:26:47.212178 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:26:47.564482 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:26:52.600546 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:27:08.777579 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:27:20.377909 :: WORKER 1 :: PARSING 27/2984
# 2025-11-22 16:27:21.680634 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:27:21.934198 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:27:31.418387 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:27:32.999648 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:27:33.650373 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:27:38.740249 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:27:59.333057 :: WORKER 2 :: PARSING 28/2984
# 2025-11-22 16:28:04.264773 :: WORKER 6 :: PARSING 29/2984
# 2025-11-22 16:28:05.179047 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:28:05.898594 :: WORKER 5 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:28:06.028274 :: WORKER 3 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:28:11.904157 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:28:18.747664 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:28:37.037542 :: WORKER 10 :: PARSING 30/2984
# 2025-11-22 16:28:44.519264 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:28:45.069609 :: WORKER 7 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:28:50.830402 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:28:51.953875 :: WORKER 0 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:28:56.270597 :: WORKER 8 :: PARSING 31/2984
# 2025-11-22 16:28:58.838752 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:29:10.361960 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:29:30.833796 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:29:37.292099 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:29:46.852883 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:29:49.120171 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:29:49.969885 :: WORKER 4 :: PARSING 32/2984
# 2025-11-22 16:29:51.530787 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:29:55.166027 :: WORKER 11 :: PARSING 33/2984
# 2025-11-22 16:29:55.315362 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:29:56.615653 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:30:06.274013 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:30:19.277256 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:30:19.728001 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:30:31.618797 :: WORKER 7 :: PARSING 34/2984
# 2025-11-22 16:30:39.618294 :: WORKER 1 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:30:39.761731 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:30:51.637286 :: WORKER 10 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:30:52.250158 :: WORKER 5 :: PARSING 35/2984
# 2025-11-22 16:30:56.473744 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:31:06.243698 :: WORKER 9 :: PARSING 36/2984
# 2025-11-22 16:31:14.559134 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:31:18.834615 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:31:24.897820 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:31:28.118254 :: WORKER 11 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:31:35.905018 :: WORKER 0 :: PARSING 37/2984
# 2025-11-22 16:31:42.466968 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:31:43.743020 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:31:48.439872 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:31:50.417994 :: WORKER 6 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:31:57.477592 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:31:58.417385 :: WORKER 3 :: PARSING 38/2984
# 2025-11-22 16:32:08.907750 :: WORKER 1 :: PARSING 39/2984
# 2025-11-22 16:32:17.533108 :: WORKER 10 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:32:22.578321 :: WORKER 6 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:32:22.955718 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:32:23.188845 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:32:29.592518 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:32:35.826698 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:32:47.196171 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:32:49.392963 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:33:15.559846 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:33:15.814268 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:33:16.090458 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:33:22.148932 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:33:27.578723 :: WORKER 9 :: PARSING 40/2984
# 2025-11-22 16:33:36.672386 :: WORKER 5 :: PARSING 41/2984
# 2025-11-22 16:33:48.918251 :: WORKER 11 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:33:50.416493 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:33:51.549668 :: WORKER 2 :: PARSING 42/2984
# 2025-11-22 16:33:57.198959 :: WORKER 8 :: PARSING 43/2984
# 2025-11-22 16:34:03.656274 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:34:11.210735 :: WORKER 10 :: PARSING 44/2984
# 2025-11-22 16:34:16.962304 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:34:18.426439 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:34:25.545643 :: WORKER 9 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:34:35.987746 :: WORKER 0 :: PARSING 45/2984
# 2025-11-22 16:34:37.232516 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:34:48.073029 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:34:48.788587 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:34:49.719956 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:35:00.258168 :: WORKER 6 :: PARSING 46/2984
# 2025-11-22 16:35:00.739560 :: WORKER 4 :: PARSING 47/2984
# 2025-11-22 16:35:02.497788 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:35:41.109423 :: WORKER 3 :: PARSING 48/2984
# 2025-11-22 16:35:41.198803 :: WORKER 11 :: PARSING 49/2984
# 2025-11-22 16:35:41.231729 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:35:47.084266 :: WORKER 7 :: PARSING 50/2984
# 2025-11-22 16:35:48.649174 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:35:55.458935 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:36:12.651422 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:36:14.475890 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:36:23.461659 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:36:25.433492 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:36:36.472102 :: WORKER 1 :: PARSING 51/2984
# 2025-11-22 16:36:42.500298 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:36:42.901540 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:36:55.792853 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:36:57.143748 :: WORKER 6 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:37:11.442857 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:37:13.665483 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:37:24.609496 :: WORKER 5 :: PARSING 52/2984
# 2025-11-22 16:37:25.391376 :: WORKER 2 :: PARSING 53/2984
# 2025-11-22 16:37:32.510633 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:37:36.592807 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:37:37.377817 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:37:50.012966 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:37:54.697656 :: WORKER 9 :: PARSING 54/2984
# 2025-11-22 16:37:58.228507 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:38:09.560028 :: WORKER 0 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:38:20.122979 :: WORKER 8 :: PARSING 55/2984
# 2025-11-22 16:38:22.357770 :: WORKER 10 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:38:23.093957 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:38:29.440949 :: WORKER 5 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:38:40.186275 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:38:46.320269 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:38:55.674340 :: WORKER 10 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:39:01.714190 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:39:03.889713 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:39:18.933446 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:39:23.788619 :: WORKER 0 :: PARSING 56/2984
# 2025-11-22 16:39:24.876978 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:39:34.055625 :: WORKER 10 :: PARSING 57/2984
# 2025-11-22 16:39:37.061927 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:39:42.929960 :: WORKER 6 :: PARSING 58/2984
# 2025-11-22 16:39:51.432385 :: WORKER 11 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:39:52.437505 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:40:07.469378 :: WORKER 7 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:40:07.837846 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:40:21.208231 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:40:22.581170 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:40:28.275089 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:40:34.214211 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:40:35.591181 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:40:35.595184 :: WORKER 7 :: PARSING 59/2984
# 2025-11-22 16:40:48.650408 :: WORKER 3 :: PARSING 60/2984
# 2025-11-22 16:40:54.799814 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:40:56.878265 :: WORKER 4 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:40:59.382190 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:41:06.681753 :: WORKER 8 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:41:06.897672 :: WORKER 1 :: PARSING 61/2984
# 2025-11-22 16:41:07.047217 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:41:14.237110 :: WORKER 4 :: PARSING 62/2984
# 2025-11-22 16:41:26.745545 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:41:27.387371 :: WORKER 5 :: PARSING 63/2984
# 2025-11-22 16:41:28.748554 :: WORKER 0 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:41:33.439074 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:41:36.529667 :: WORKER 11 :: PARSING 64/2984
# 2025-11-22 16:41:38.460135 :: WORKER 8 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:41:40.814194 :: WORKER 2 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:41:50.364259 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:42:04.603102 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:42:04.952641 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:42:14.800270 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:42:18.464401 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:42:24.987264 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:42:31.473470 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:42:37.412103 :: WORKER 7 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:42:41.317933 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:42:41.326090 :: WORKER 2 :: PARSING 65/2984
# 2025-11-22 16:42:43.237184 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:42:58.871606 :: WORKER 3 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:43:10.709654 :: WORKER 7 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:43:16.593535 :: WORKER 8 :: PARSING 66/2984
# 2025-11-22 16:43:21.689881 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:43:24.092372 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:43:27.213223 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:43:27.549278 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:43:43.930249 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:43:52.489797 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:43:53.205474 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:43:57.066825 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:44:01.058936 :: WORKER 6 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:44:05.500838 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:44:14.124196 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:44:14.575899 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:44:18.666506 :: WORKER 10 :: PARSING 67/2984
# 2025-11-22 16:44:19.645301 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:44:26.807881 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:44:31.928510 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:44:45.247317 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:44:53.018705 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:45:00.443446 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:45:00.515685 :: WORKER 6 :: PARSING 68/2984
# 2025-11-22 16:45:04.282365 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:45:06.583499 :: WORKER 0 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:45:09.486890 :: WORKER 11 :: PARSING 69/2984
# 2025-11-22 16:45:10.019658 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:45:17.106019 :: WORKER 10 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:45:22.204028 :: WORKER 9 :: PARSING 70/2984
# 2025-11-22 16:45:29.423549 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:45:32.957164 :: WORKER 4 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:45:35.787448 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:45:37.197208 :: WORKER 0 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:45:46.581870 :: WORKER 7 :: PARSING 71/2984
# 2025-11-22 16:46:02.244921 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:46:03.379714 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:46:04.943434 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:46:08.394430 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:46:10.327874 :: WORKER 0 :: Rate Limit Hit (2 retries left)
# 2025-11-22 16:46:14.098701 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:46:18.662336 :: WORKER 8 :: PARSING 72/2984
# 2025-11-22 16:46:24.498938 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:46:33.721622 :: WORKER 3 :: PARSING 73/2984
# 2025-11-22 16:46:37.309140 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:46:48.438077 :: WORKER 5 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:46:48.564617 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:46:49.170236 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:46:52.684777 :: WORKER 1 :: PARSING 74/2984
# 2025-11-22 16:47:06.301205 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:47:06.502719 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:47:16.745009 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:47:17.963003 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:47:21.322228 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:47:21.798694 :: WORKER 5 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:47:28.932559 :: WORKER 0 :: PARSING 75/2984
# 2025-11-22 16:47:33.071617 :: WORKER 4 :: PARSING 76/2984
# 2025-11-22 16:47:46.391862 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:47:46.665398 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:47:52.774710 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:47:52.970111 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:48:00.109706 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:48:09.591395 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:48:10.946330 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:48:17.141546 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:48:24.651723 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:48:30.139732 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:48:36.475897 :: WORKER 2 :: PARSING 77/2984
# 2025-11-22 16:48:59.608191 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:49:00.261862 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:49:00.965175 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:49:18.052092 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:49:34.923357 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:49:35.113296 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:49:35.257537 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:49:40.715926 :: WORKER 11 :: PARSING 78/2984
# 2025-11-22 16:49:50.785007 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:49:56.453733 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:49:58.160558 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:49:59.672393 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:50:02.414684 :: WORKER 5 :: PARSING 79/2984
# 2025-11-22 16:50:03.088858 :: WORKER 6 :: PARSING 80/2984
# 2025-11-22 16:50:12.147749 :: WORKER 10 :: PARSING 81/2984
# 2025-11-22 16:50:23.174840 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:50:23.232039 :: WORKER 9 :: PARSING 82/2984
# 2025-11-22 16:50:23.328278 :: WORKER 3 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:50:24.682544 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:50:29.994132 :: WORKER 1 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:50:30.036837 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:50:50.933042 :: WORKER 8 :: PARSING 83/2984
# 2025-11-22 16:50:57.694131 :: WORKER 7 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:51:00.118397 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:01.321485 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:04.201132 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:21.645397 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:22.719212 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:26.229379 :: WORKER 4 :: PARSING 84/2984
# 2025-11-22 16:51:39.219918 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:42.725386 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:43.895052 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:43.939030 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:49.516594 :: WORKER 1 :: PARSING 85/2984
# 2025-11-22 16:51:57.292894 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:51:58.374393 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:52:01.528196 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:52:10.988588 :: WORKER 0 :: PARSING 86/2984
# 2025-11-22 16:52:14.089374 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:52:25.348596 :: WORKER 7 :: PARSING 87/2984
# 2025-11-22 16:52:26.574797 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:52:31.298709 :: WORKER 4 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:52:43.512804 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:52:50.140198 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:52:50.590457 :: WORKER 3 :: PARSING 88/2984
# 2025-11-22 16:53:16.014260 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:53:16.362568 :: WORKER 10 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:53:23.039916 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:53:23.193418 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:53:42.824390 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:53:43.189630 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:53:56.000120 :: WORKER 6 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:53:56.654321 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:54:11.597415 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:54:23.729648 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:54:24.444382 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:54:28.003129 :: WORKER 11 :: PARSING 89/2984
# 2025-11-22 16:54:33.968786 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:54:41.992210 :: WORKER 9 :: PARSING 90/2984
# 2025-11-22 16:54:42.177870 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:54:43.316054 :: WORKER 1 :: PARSING 91/2984
# 2025-11-22 16:54:47.794229 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:54:56.834660 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:55:00.044877 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:55:22.264842 :: WORKER 7 :: PARSING 92/2984
# 2025-11-22 16:55:22.716136 :: WORKER 2 :: PARSING 93/2984
# 2025-11-22 16:55:30.252408 :: WORKER 0 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:55:32.481286 :: WORKER 5 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:55:37.316786 :: WORKER 10 :: PARSING 94/2984
# 2025-11-22 16:55:37.628153 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:55:44.547641 :: WORKER 4 :: PARSING 95/2984
# 2025-11-22 16:55:56.876925 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:56:04.289816 :: WORKER 3 :: PARSING 96/2984
# 2025-11-22 16:56:08.798762 :: WORKER 6 :: PARSING 97/2984
# 2025-11-22 16:56:09.618121 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:56:25.228004 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:56:26.647296 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:56:26.879934 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:56:31.705572 :: WORKER 8 :: PARSING 98/2984
# 2025-11-22 16:56:44.855369 :: WORKER 5 :: PARSING 99/2984
# 2025-11-22 16:56:50.915245 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:56:58.801380 :: WORKER 4 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:57:05.841513 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:57:07.845390 :: WORKER 0 :: PARSING 100/2984
# 2025-11-22 16:57:16.402909 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:57:16.434902 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:57:18.192341 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:57:33.892324 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:57:35.151000 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:57:48.840708 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:57:59.720926 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:58:04.933598 :: WORKER 4 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:58:07.648735 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:58:24.015917 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:58:24.578767 :: WORKER 1 :: PARSING 101/2984
# 2025-11-22 16:58:30.113349 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:58:36.608069 :: WORKER 4 :: Rate Limit Hit (3 retries left)
# 2025-11-22 16:58:44.605234 :: WORKER 9 :: PARSING 102/2984
# 2025-11-22 16:58:45.082399 :: WORKER 7 :: PARSING 103/2984
# 2025-11-22 16:58:51.038600 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:58:59.299945 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# /home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/neo4j/_sync/work/result.py:625: UserWarning: Expected a result with a single record, but found multiple.
#   warn(
# 2025-11-22 16:59:09.563601 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:59:12.870868 :: WORKER 2 :: PARSING 104/2984
# 2025-11-22 16:59:16.029747 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:59:20.115837 :: WORKER 10 :: PARSING 105/2984
# 2025-11-22 16:59:27.497038 :: WORKER 11 :: PARSING 106/2984
# 2025-11-22 16:59:29.701207 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:59:33.575245 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:59:41.006455 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:59:41.409069 :: WORKER 0 :: Rate Limit Hit (4 retries left)
# 2025-11-22 16:59:46.611546 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 16:59:55.202221 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:00:00.598316 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:00:09.368458 :: WORKER 3 :: PARSING 107/2984
# 2025-11-22 17:00:13.624339 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:00:15.304116 :: WORKER 8 :: PARSING 108/2984
# 2025-11-22 17:00:16.107592 :: WORKER 10 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:00:19.541932 :: WORKER 11 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:00:29.956996 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:00:47.300478 :: WORKER 10 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:00:59.623018 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:01:00.500230 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:01:04.840083 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:01:18.977241 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:01:32.312436 :: WORKER 6 :: PARSING 109/2984
# 2025-11-22 17:01:32.410572 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:01:33.338711 :: WORKER 4 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:01:45.498171 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:01:53.236918 :: WORKER 3 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:01:55.051126 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:01:57.489864 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:02:12.914126 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:02:17.363222 :: WORKER 5 :: PARSING 110/2984
# 2025-11-22 17:02:28.253308 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:02:36.600857 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:02:42.779891 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:02:48.021328 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:02:58.043518 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:03:07.793829 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:03:16.492733 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:03:21.265120 :: WORKER 7 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:03:24.283118 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:03:27.168097 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:03:34.528137 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:03:40.166258 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:03:50.721163 :: WORKER 11 :: PARSING 111/2984
# 2025-11-22 17:03:50.926454 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:03:55.652239 :: WORKER 9 :: PARSING 112/2984
# 2025-11-22 17:03:57.253357 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:03:57.974054 :: WORKER 0 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:04:02.977756 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:04:03.806357 :: WORKER 7 :: PARSING 113/2984
# 2025-11-22 17:04:11.867400 :: WORKER 10 :: PARSING 114/2984
# 2025-11-22 17:04:15.925372 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:04:17.988071 :: WORKER 8 :: PARSING 115/2984
# 2025-11-22 17:04:24.188414 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:04:30.360437 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:04:32.361829 :: WORKER 0 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:04:36.855714 :: WORKER 4 :: PARSING 116/2984
# 2025-11-22 17:04:37.044311 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:04:54.642124 :: WORKER 3 :: PARSING 117/2984
# 2025-11-22 17:04:56.416395 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:05:01.835844 :: WORKER 7 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:05:06.222733 :: WORKER 1 :: PARSING 118/2984
# 2025-11-22 17:05:12.391262 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:05:12.809775 :: WORKER 6 :: PARSING 119/2984
# 2025-11-22 17:05:19.231423 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:05:22.414021 :: WORKER 0 :: PARSING 120/2984
# 2025-11-22 17:05:23.827507 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:05:44.084265 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:05:57.263272 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:05:57.796416 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:06:04.653539 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:06:04.842230 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:06:09.272118 :: WORKER 5 :: PARSING 121/2984
# 2025-11-22 17:06:30.969481 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:06:31.417243 :: WORKER 8 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:06:31.696286 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:06:32.741314 :: WORKER 11 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:06:37.747422 :: WORKER 6 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:06:53.694743 :: WORKER 2 :: PARSING 122/2984
# 2025-11-22 17:06:59.948085 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:07:04.923325 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:07:26.618581 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:07:31.449220 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:07:48.956278 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:07:55.622286 :: WORKER 9 :: PARSING 123/2984
# 2025-11-22 17:07:56.205240 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:08:06.787937 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:08:16.615886 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:08:27.535240 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:08:29.602837 :: WORKER 6 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:08:38.215136 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:08:53.326704 :: WORKER 11 :: PARSING 124/2984
# 2025-11-22 17:08:59.810243 :: WORKER 10 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:09:00.689574 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:09:10.737402 :: WORKER 9 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:09:17.822217 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:09:23.033305 :: WORKER 0 :: PARSING 125/2984
# 2025-11-22 17:09:25.874284 :: WORKER 1 :: PARSING 126/2984
# 2025-11-22 17:09:32.898943 :: WORKER 7 :: PARSING 127/2984
# 2025-11-22 17:09:37.285758 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:09:39.195614 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:09:39.991792 :: WORKER 4 :: PARSING 128/2984
# 2025-11-22 17:09:41.996141 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:09:43.281859 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:09:59.359943 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:00.522689 :: WORKER 10 :: PARSING 129/2984
# 2025-11-22 17:10:04.065781 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:10.553171 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:11.244855 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:17.990235 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:23.707540 :: WORKER 6 :: PARSING 130/2984
# 2025-11-22 17:10:25.619484 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:31.486827 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:38.132462 :: WORKER 8 :: PARSING 131/2984
# 2025-11-22 17:10:48.291088 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:52.911811 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:56.955798 :: WORKER 3 :: PARSING 132/2984
# 2025-11-22 17:10:58.107974 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:10:58.403575 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:11:09.483376 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:11:22.410383 :: WORKER 5 :: PARSING 133/2984
# 2025-11-22 17:11:23.242082 :: WORKER 6 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:11:28.539195 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:11:35.466938 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:11:51.621912 :: WORKER 8 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:11:53.025152 :: WORKER 0 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:03.997728 :: WORKER 7 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:04.609637 :: WORKER 9 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:05.058281 :: WORKER 3 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:06.778425 :: WORKER 2 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:09.474629 :: WORKER 6 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:09.572370 :: WORKER 11 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:13.904906 :: WORKER 4 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:14.230537 :: WORKER 10 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:15.159198 :: WORKER 5 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:16.736311 :: WORKER 1 :: Rate Limit Hit (5 retries left)
# 2025-11-22 17:12:25.193962 :: WORKER 0 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:25.265823 :: WORKER 8 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:35.933279 :: WORKER 7 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:37.074515 :: WORKER 9 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:38.664052 :: WORKER 2 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:39.043960 :: WORKER 3 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:42.847331 :: WORKER 11 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:43.076018 :: WORKER 6 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:45.661489 :: WORKER 5 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:45.946792 :: WORKER 4 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:46.774015 :: WORKER 10 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:48.607130 :: WORKER 1 :: Rate Limit Hit (4 retries left)
# 2025-11-22 17:12:55.659653 :: WORKER 8 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:12:59.676485 :: WORKER 0 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:08.846620 :: WORKER 7 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:10.494306 :: WORKER 9 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:11.564104 :: WORKER 2 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:12.230395 :: WORKER 3 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:14.122289 :: WORKER 11 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:14.588894 :: WORKER 6 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:17.853637 :: WORKER 10 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:18.097238 :: WORKER 5 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:19.373565 :: WORKER 4 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:23.111976 :: WORKER 1 :: Rate Limit Hit (3 retries left)
# 2025-11-22 17:13:26.649075 :: WORKER 8 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:31.887720 :: WORKER 0 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:40.435254 :: WORKER 7 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:43.405622 :: WORKER 2 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:43.553259 :: WORKER 9 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:45.060061 :: WORKER 3 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:46.095917 :: WORKER 11 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:47.965920 :: WORKER 6 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:48.168882 :: WORKER 10 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:52.672441 :: WORKER 5 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:53.815752 :: WORKER 4 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:13:54.146341 :: WORKER 1 :: Rate Limit Hit (2 retries left)
# 2025-11-22 17:14:00.100871 :: WORKER 8 :: Rate Limit Hit (1 retries left)
# 2025-11-22 17:14:05.989273 :: WORKER 0 :: Rate Limit Hit (1 retries left)
# 2025-11-22 17:14:14.033396 :: WORKER 7 :: Rate Limit Hit (1 retries left)
# Exception in thread Thread-12 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:15.101137 :: WORKER 8 :: MAX RETRIES HIT
# 2025-11-22 17:14:16.074106 :: WORKER 9 :: Rate Limit Hit (1 retries left)
# 2025-11-22 17:14:17.094041 :: WORKER 3 :: Rate Limit Hit (1 retries left)
# 2025-11-22 17:14:17.716704 :: WORKER 2 :: Rate Limit Hit (1 retries left)
# 2025-11-22 17:14:17.874334 :: WORKER 11 :: Rate Limit Hit (1 retries left)
# 2025-11-22 17:14:18.545022 :: WORKER 6 :: Rate Limit Hit (1 retries left)
# Exception in thread Thread-4 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:20.989457 :: WORKER 0 :: MAX RETRIES HIT
# 2025-11-22 17:14:22.773567 :: WORKER 10 :: Rate Limit Hit (1 retries left)
# 2025-11-22 17:14:26.188971 :: WORKER 5 :: Rate Limit Hit (1 retries left)
# 2025-11-22 17:14:27.253309 :: WORKER 1 :: Rate Limit Hit (1 retries left)
# 2025-11-22 17:14:27.396580 :: WORKER 4 :: Rate Limit Hit (1 retries left)
# Exception in thread Thread-11 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:29.033656 :: WORKER 7 :: MAX RETRIES HIT
# Exception in thread Thread-13 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:31.074417 :: WORKER 9 :: MAX RETRIES HIT
# Exception in thread Thread-7 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:32.094293 :: WORKER 3 :: MAX RETRIES HIT
# Exception in thread Thread-6 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:32.716956 :: WORKER 2 :: MAX RETRIES HIT
# Exception in thread Thread-15 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:32.874511 :: WORKER 11 :: MAX RETRIES HIT
# Exception in thread Thread-10 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:33.545173 :: WORKER 6 :: MAX RETRIES HIT
# Exception in thread Thread-14 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:37.773844 :: WORKER 10 :: MAX RETRIES HIT
# Exception in thread Thread-9 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:41.189200 :: WORKER 5 :: MAX RETRIES HIT
# Exception in thread Thread-5 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:42.253621 :: WORKER 1 :: MAX RETRIES HIT
# Exception in thread Thread-8 (qa_val_vsc_worker):
# Traceback (most recent call last):
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "/home/overlord/anaconda3/envs/bwe_312/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_889948/1188436977.py", line 58, in qa_val_vsc_worker
# Exception: 2025-11-22 17:14:42.396757 :: WORKER 4 :: MAX RETRIES HIT

# %%
eval_qas.to_csv('../data/eval_qas_with_node_ids.csv')

# %%
# need to prune based on whether or not each ground truth was used for the Q&A pair
# standardize/look up ids for ground truth
